# %%
import hnswlib
import numpy as np 
import struct
import heapq
import time

# %%
def mmap_fvecs(fname):
    x = np.memmap(fname, dtype='int32', mode='r')
    d = x[0]
    return x.view('float32').reshape(-1, d + 1)[:, 1:]

def mmap_bvecs(fname):
    x = np.memmap(fname, dtype='uint8', mode='r')
    d = x[:4].view('int32')[0]
    return x.reshape(-1, d + 4)[:, 4:]

def ivecs_read(fname):
    a = np.fromfile(fname, dtype='int32')
    d = a[0]
    # Wenqi: Format of ground truth (for 10000 query vectors):
    #   1000(topK), [1000 ids]
    #   1000(topK), [1000 ids]
    #        ...     ...
    #   1000(topK), [1000 ids]
    # 10000 rows in total, 10000 * 1001 elements, 10000 * 1001 * 4 bytes
    return a.reshape(-1, d + 1)[:, 1:].copy()

def fvecs_read(fname):
    return ivecs_read(fname).view('float32')

# %%
dbname = 'SIFT1M'
index_path='../indexes/{}_index.bin'.format(dbname)
dim=128

if dbname.startswith('SIFT'):
    # SIFT1M to SIFT1000M
    dbsize = int(dbname[4:-1])
    xb = mmap_bvecs('/mnt/scratch/wenqi/Faiss_experiments/bigann/bigann_base.bvecs')
    xq = mmap_bvecs('/mnt/scratch/wenqi/Faiss_experiments/bigann/bigann_query.bvecs')
    gt = ivecs_read('/mnt/scratch/wenqi/Faiss_experiments/bigann/gnd/idx_%dM.ivecs' % dbsize)

    N_VEC = int(dbsize * 1000 * 1000)

    # trim xb to correct size
    xb = xb[:dbsize * 1000 * 1000]

    # Wenqi: load xq to main memory and reshape
    xq = xq.astype('float32').copy()
    xq = np.array(xq, dtype=np.float32)
    gt = np.array(gt, dtype=np.int32)

    print("Vector shapes:")
    print("Base vector xb: ", xb.shape)
    print("Query vector xq: ", xq.shape)
    print("Ground truth gt: ", gt.shape)
else:
    print('unknown dataset', dbname, file=sys.stderr)
    sys.exit(1)
# Out:
# Vector shapes:
# Base vector xb:  (1000000, 128)
# Query vector xq:  (10000, 128)
# Ground truth gt:  (10000, 1000)

# %% [markdown]
# ## Core HNSW load and search

# %%
def convertBytes(bytestring, dtype='int'):
    """
    convert bytes to a single element
    dtype = {int, long, float, double}
    struct: https://docs.python.org/3/library/struct.html
    """ 
    # int from bytes is much faster than struct.unpack
    if dtype =='int' or dtype == 'long': 
        return int.from_bytes(bytestring, byteorder='little', signed=False)
    elif dtype == 'float': 
        return struct.unpack('f', bytestring)[0]
    elif dtype == 'double': 
        return struct.unpack('d', bytestring)[0]
    else:
        raise ValueError 

# Wenqi: the fastest way to load a bytestring list is to use *** np.frombuffer ***
def convertBytesList(bytestring, dtype='int'):
    """
    Given a byte string, return the value list
    """
    result_list = []
    if dtype == 'int' or dtype == 'float':
        dsize = 4
    elif dtype == 'long' or dtype == 'double':
        dsize = 8
    else:
        raise ValueError 
        
    start_pointer = 0
    for i in range(len(bytestring) // dsize):
        result_list.append(convertBytes(
            bytestring[start_pointer: start_pointer + dsize], dtype=dtype))
        start_pointer += dsize
    return result_list

def calculateDist(query_data, db_vec):
    """
    HNSWLib returns L2 square distance, so do we
        both inputs are 1-d np array
    """
    # return l2 distance between two points
    return np.sum((query_data - db_vec) ** 2)


def merge_two_distance_list(list_A, list_B, k):
    """
    merge two lists by selecting the k pairs of the smallest distance
    input:
        both list has format [(dist, ID), (dist, ID), ...]
    return:
        a result list, with ascending distance (the first contains the largest distance)
    """
    
    results_heap = []
    for i in range(len(list_A)):
        dist, server_ID, vec_ID = list_A[i]
        heapq.heappush(results_heap, (-dist, server_ID, vec_ID))
    for i in range(len(list_B)):
        dist, server_ID, vec_ID = list_B[i]
        heapq.heappush(results_heap, (-dist, server_ID, vec_ID))

    while len(results_heap) > k:
        heapq.heappop(results_heap)

    results = []
    while len(results_heap) > 0:
        dist, server_ID, vec_ID = results_heap[0]
        results.append((-dist, server_ID, vec_ID))
        heapq.heappop(results_heap)
    results.reverse()
            
    return results

# %%
import struct 

        
class HNSW_index():
    
    """
    Returned result list always in the format of (dist, server_ID, vec_ID),
        in ascending distance order (the first result is the nearest neighbor)
    """
    
    def __init__(self, local_server_ID=0, dim=128):
        
        self.dim = dim
        self.local_server_ID = local_server_ID
        
        # Meta Info
        self.offsetLevel0_ = None
        self.max_elements_ = None
        self.cur_element_count = None
        self.size_data_per_element_ = None
        self.label_offset_ = None
        self.offsetData_ = None
        self.maxlevel_ = None
        self.enterpoint_node_ = None
        self.maxM_ = None
        self.maxM0_ = None
        self.M_ = None
        self.mult_ = None # the probability that a node is one a higher level
        self.ef_construction_ = None
        
        # ground layer, all with length of cur_element_count
        self.links_count_l0 = None # a list of link_count
        self.links_l0 = None # a list of links per vector
        self.data_l0 = None # a list of vectors
        label_l0 = None # a list of vector IDs
        
        # upper layers, all with length of cur_element_count
        self.element_levels_ = None # the level per vector
        self.links = None # the upper layer link info (link count + links)
        
        # remote nodes, order according to local ID (not label ID)
        #  remote_links: an 2-D array (cur_element_count, k), 
        #    each element is a tuple: (server_ID, vector_ID)
        self.remote_links_count = None
        self.remote_links = None
        
    def load_meta_info(self, index_bin):
        """
        index_bin = hnswlib index binary 
        
        HNSW save index order:
            https://github.com/WenqiJiang/hnswlib-eval/blob/master/hnswlib/hnswalg.h#L588-L616
        """
        self.offsetLevel0_ = int.from_bytes(data[0:8], byteorder='little', signed=False)
        self.max_elements_ = int.from_bytes(data[8:16], byteorder='little', signed=False)
        self.cur_element_count = int.from_bytes(data[16:24], byteorder='little', signed=False)
        self.size_data_per_element_ = int.from_bytes(data[24:32], byteorder='little', signed=False)
        self.label_offset_ = int.from_bytes(data[32:40], byteorder='little', signed=False)
        self.offsetData_ = int.from_bytes(data[40:48], byteorder='little', signed=False)
        self.maxlevel_ = int.from_bytes(data[48:52], byteorder='little', signed=False)
        self.enterpoint_node_ = int.from_bytes(data[52:56], byteorder='little', signed=False)
        self.maxM_ = int.from_bytes(data[56:64], byteorder='little', signed=False)
        self.maxM0_ = int.from_bytes(data[64:72], byteorder='little', signed=False)
        self.M_ = int.from_bytes(data[72:80], byteorder='little', signed=False)
        self.mult_ = struct.unpack('d', data[80:88])[0] # the probability that a node is one a higher level
        self.ef_construction_ = int.from_bytes(data[88:96], byteorder='little', signed=False)
        

        print("offsetLevel0_", self.offsetLevel0_)
        print("max_elements_", self.max_elements_)
        print("cur_element_count", self.cur_element_count)
        print("size_data_per_element_", self.size_data_per_element_)
        print("label_offset_", self.label_offset_)
        print("offsetData_", self.offsetData_)
        print("maxlevel_", self.maxlevel_)
        print("enterpoint_node_", self.enterpoint_node_)
        print("maxM_", self.maxM_)
        print("maxM0_", self.maxM0_)
        print("M_", self.M_)
        print("mult_", self.mult_)
        print("ef_construction_", self.ef_construction_)
        
    
    def load_ground_layer(self, index_bin):
        """
        Get the ground layer vector ID, vectors, and links:
            links_count_l0: vec_num
            links_l0: maxM0_ * vec_num 
            data_l0: (dim, vec_num)
            label_l0: vec_num
        """
        
        # Layer 0 data 
        start_byte_pointer = 96
        delta = self.cur_element_count * self.size_data_per_element_
        data_level0 = index_bin[start_byte_pointer: start_byte_pointer + delta]
        
        size = len(data_level0)
        self.links_count_l0 = []
        self.links_l0 = np.zeros((self.cur_element_count, self.maxM0_), dtype=int)
        self.data_l0 = np.zeros((self.cur_element_count, self.dim))
        self.label_l0 = []

        data_l0_list = []
        
        assert len(data_level0) == self.size_data_per_element_ * self.cur_element_count
        
        size_link_count = 4
        size_links = self.maxM0_ * 4
        size_vectors = self.dim * 4
        size_label = 8
        
        assert self.size_data_per_element_ == \
            size_link_count + size_links + size_vectors + size_label
            
        for i in range(self.cur_element_count):
            # per ground layer node: (link_count (int), links (int array of len=maxM0_), 
            #    vector (float array of len=dim, vector ID (long)))
            
            addr_link_count = i * self.size_data_per_element_ 
            addr_links = addr_link_count + size_link_count
            addr_vectors = addr_links + size_links
            addr_label = addr_vectors + size_vectors
            
            tmp_bytes = data_level0[addr_link_count: addr_link_count + size_link_count]
            self.links_count_l0.append(convertBytes(tmp_bytes, dtype='int'))
        
            tmp_bytes = data_level0[addr_links: addr_links + size_links]
            self.links_l0[i] = np.frombuffer(tmp_bytes, dtype=np.int32)
            
            tmp_bytes = data_level0[addr_vectors: addr_vectors + size_vectors]
            self.data_l0[i] = np.frombuffer(tmp_bytes, dtype=np.float32)
            
            tmp_bytes = data_level0[addr_label: addr_label + size_label]
            self.label_l0.append(convertBytes(tmp_bytes, dtype='long'))


    def load_upper_layers(self, index_bin):
        """
        Get the upper layer info:
            element_levels_: the levels of each vector
            links: list of upper links
        """
        
        # meta + ground data
        start_byte_pointer = 96 + self.max_elements_ * self.size_data_per_element_
        
        # Upper layers
        links_count = 0
        size_links_per_element_ = self.maxM_ * 4 + 4
        self.element_levels_ = []
        self.links = []

        for i in range(self.cur_element_count):
            tmp_bytes = index_bin[start_byte_pointer:start_byte_pointer+4]
            linkListSize = convertBytes(tmp_bytes, dtype='int')
            start_byte_pointer += 4
            
            # if an element is only on ground layer, it has no links on upper layers at all
            if linkListSize == 0:
                self.element_levels_.append(0)
                self.links.append([])
            else:
                level = int(linkListSize / size_links_per_element_)
                self.element_levels_.append(level)
                tmp_bytes = index_bin[start_byte_pointer:start_byte_pointer+linkListSize]
                links_tmp = list(np.frombuffer(tmp_bytes, dtype=np.int32))
                start_byte_pointer += linkListSize
                links_count += linkListSize / 4;
                self.links.append(links_tmp)

        assert start_byte_pointer == len(index_bin) # 6606296

    def insertRemote(self, remote_hnswlib_indexes, remote_server_IDs, ef=128):
        """
        Input: 
            remote_hnswlib_indexes: a list of remote_hnswlib_index
                remote_hnswlib_index: index loaded by remote memory (hnswlib object)
            remote_server_IDs: a list of remote index IDs respective to remote_hnswlib_indexes
                e.g., this is server 1, and there are four servers in totol,
                    then the remote index IDs should be [0, 2, 3]
        """
        self.remote_links_count = []
        self.remote_links = []
        
        remote_I_list = []
        remote_D_list = []
        remote_server_ID_list = []
        
        k = self.maxM0_
        
        assert len(remote_hnswlib_indexes) == len(remote_server_IDs)
        
        # query all servers
        for i in range(len(remote_server_IDs)):
            remote_hnswlib_index = remote_hnswlib_indexes[i]
            remote_server_ID = remote_server_IDs[i]
        
            query = self.data_l0
            remote_hnswlib_index.set_ef(ef)
            I, D = remote_hnswlib_index.knn_query(query, k=k)
            remote_I_list.append(I)
            remote_D_list.append(D)
            remote_server_ID_list.append(
                np.ones((I.shape[0], I.shape[1]), dtype=np.int32) * int(remote_server_ID))
    
        # merge results per server
        remote_I = np.concatenate(remote_I_list, axis=1)
        remote_D = np.concatenate(remote_D_list, axis=1)
        remote_server_ID = np.concatenate(remote_server_ID_list, axis=1)
        
        D_server_ID_I_list = [[] for i in range(remote_I.shape[0])]
        server_ID_I_list= [[] for i in range(remote_I.shape[0])]
        for i in range(remote_I.shape[0]):
            for j in range(remote_I.shape[1]):
                D_server_ID_I_list[i].append((remote_D[i][j], remote_server_ID[i][j], remote_I[i][j]))
            D_server_ID_I_list[i].sort()
            D_server_ID_I_list[i] = D_server_ID_I_list[i][:k]
            server_ID_I_list[i] = [(s, i) for d, s, i in D_server_ID_I_list[i]]
                
        
        self.remote_links_count = [k for i in range(self.cur_element_count)]
        #  remote_links: an 2-D array (cur_element_count x k), 
        #    each element is a tuple: (server_ID, vector_ID)
        self.remote_links = server_ID_I_list
        

    def searchKnn(self, q_data, k, ef, debug=False):
        """
        result a list of (distance, vec_ID) in ascending distance
        """
        
        ep_node = self.enterpoint_node_
        num_elements = self.cur_element_count
        max_level = self.maxlevel_
        links_count_l0 = self.links_count_l0
        links_l0 = self.links_l0
        data_l0 = self.data_l0
        links = self.links
        label_l0 = self.label_l0
        dim = self.dim
        
        currObj = ep_node
        currVec = data_l0[currObj]
        curdist = calculateDist(q_data, currVec)
        
        search_path_local_ID = set()
        search_path_vec_ID = set()
        
        # search upper layers
        for level in reversed(range(1, max_level+1)):
            if debug:
                print("")
                print("level: ", level)
            changed = True
            while changed:
                if debug:
                    print("current object: ", currObj, ", current distance: ", curdist)
                search_path_local_ID.add(currObj)
                changed = False
                ### Wenqi: here, assuming Node ID can be used to retrieve upper links (which is not true for indexes with ID starting from non-0)
                if (len(links[currObj])==0):
                    break
                else:
                    start_index = (level-1) * 17
                    size = links[currObj][start_index]
                    if debug:
                        print("size of neighbors: ", size) 
                    neighbors = links[currObj][(start_index+1):(start_index+17)]
                    for i in range(size):
                        cand = neighbors[i]
                        currVec = data_l0[cand]
                        dist = calculateDist(q_data, currVec)
                        if debug:
                            print("cand: ", cand, ", dist: ", dist)
                        if (dist < curdist):
                            curdist = dist
                            currObj = cand
                            changed = True
                            if debug:
                                print("changed")
                    if debug:
                        print("one node finish")
                        print("")

        # search in ground layer
        if debug:
            print("")
            print("level: 0")
        visited_array = set() # default 0
        top_candidates = []
        candidate_set = []
        lowerBound = curdist 
        # By default heap queue is a min heap: https://docs.python.org/3/library/heapq.html
        # candidate_set = candidate list, min heap
        # top_candidates = dynamic list (potential results), max heap
        # compare min(candidate_set) vs max(top_candidates)
        heapq.heappush(top_candidates, (-curdist, currObj))
        heapq.heappush(candidate_set,(curdist, currObj))
        visited_array.add(currObj) 

        while len(candidate_set)!=0:
            current_node_pair = candidate_set[0]
            if ((current_node_pair[0] > lowerBound)):
                break
            heapq.heappop(candidate_set)
            current_node_id = current_node_pair[1]
            search_path_local_ID.add(current_node_id)
            size = links_count_l0[current_node_id]
            if debug:
                print("current object: ", current_node_id)
                print("size of neighbors: ", size)
            for i in range(size):
                candidate_id = links_l0[current_node_id][i]
                if (candidate_id not in visited_array):
                    visited_array.add(candidate_id)
                    currVec = data_l0[candidate_id]
                    dist = calculateDist(q_data, currVec)
                    if debug:
                        print("current object: ", candidate_id, ", current distance: ", dist, ", lowerBound: ", lowerBound)
                    if (len(top_candidates) < ef or lowerBound > dist):
                        if debug:
                            print("added")
                        heapq.heappush(candidate_set, (dist, candidate_id))
                        heapq.heappush(top_candidates, (-dist, candidate_id))
                    if (len(top_candidates) > ef):
                        heapq.heappop(top_candidates)
                    if (len(top_candidates)!=0):
                        lowerBound = -top_candidates[0][0]
                else :
                    if debug:
                        print("current object: ", candidate_id, ", visited already")
            if debug:
                print("one node finishes")
                print("")

        while len(top_candidates) > k:
            heapq.heappop(top_candidates)

        result = []
        while len(top_candidates) > 0:
            candidate_pair = top_candidates[0]
            # Wenqi: here, replace the local candidate ID by real node ID, great!
            result.append([-candidate_pair[0], self.local_server_ID, label_l0[candidate_pair[1]]])
            heapq.heappop(top_candidates)
        result.reverse()
            
        for local_ID in search_path_local_ID:
            search_path_vec_ID.add(label_l0[local_ID])

        return result, search_path_local_ID, search_path_vec_ID
        
    def searchKnnPlusRemoteCache(self, q_data, k, ef, all_vectors, debug=False):
        """
        Seach local vectors + cached remote vectors
        Input: 
            all vectors = the entire dataset with N_TOTAL d-dimensional vectors, used to do remote search
        Output:
            a list of local results, in asending distance
            a list of remote results (only with the vectors one hop away from local), in asending distance
            a list of merged results, in asending distance
            whether one should search remote (True/False)
        """
        local_results, search_path_local_ID, search_path_vec_ID = self.searchKnn(q_data, k, ef, debug=debug)
        # get the list of remote vectors that should be visited
        remote_server_ID_vec_ID_list = []
        
        for local_ID in search_path_local_ID:
            link_count = self.remote_links_count[local_ID]
            for i in range(link_count):
                remote_server_ID_vec_ID_list.append(self.remote_links[local_ID][i])
    
        remote_results_heap = []
        for remote_server_ID, vec_ID in remote_server_ID_vec_ID_list:
            dist = np.sum((q_data - all_vectors[vec_ID]) ** 2)
            heapq.heappush(remote_results_heap, (-dist, remote_server_ID, vec_ID))
            
        while len(remote_results_heap) > k:
            heapq.heappop(remote_results_heap)

        remote_results = []
        while len(remote_results_heap) > 0:
            dist, remote_server_ID, vec_ID = remote_results_heap[0]
            remote_results.append((-dist, remote_server_ID, vec_ID))
            heapq.heappop(remote_results_heap)
        remote_results.reverse()
            
        # Merge local + remote
        results = merge_two_distance_list(local_results, remote_results, k)
            
        if remote_results[0][0] < local_results[0][0]:
            search_remote = True
            remote_server_ID = remote_results[0][1]
        else:
            search_remote = False
            remote_server_ID = -1
            
        return results, local_results, remote_results, search_remote, remote_server_ID
        

        
    def searchKnnPlusRemote(self, q_data, k, ef, all_vectors, remote_hnswlib_indexes, remote_server_IDs, debug=False):
        """
        Search local vectors, hop to remote index ***(currently only support 1 index)*** when needed
            *** Thus, this is only a testing functino, in reality, there should be a global search 
                function allowing multiple hops between servers ***
        Input: 
            all vectors = the entire dataset with N_TOTAL d-dimensional vectors, used to do remote search
            remote_hnswlib_indexes: a list of remote_hnswlib_index
                remote_hnswlib_index: index loaded by remote memory (hnswlib object)
            remote_server_IDs: a list of remote index IDs respective to remote_hnswlib_indexes
                e.g., this is server 1, and there are four servers in totol,
                    then the remote index IDs should be [0, 2, 3]
        Output:
            a list of local results, in distance ascending order
            a list of remote results (only with the vectors one hop away from local)
            a list of merged results
            whether one should search remote (True/False)
        """
        local_plus_cach_results, local_results, remote_results, search_remote, remote_server_ID = \
            self.searchKnnPlusRemoteCache(q_data, k, ef, all_vectors, debug=debug)
        
        if search_remote:
            for i, ids in enumerate(remote_server_IDs):
                if ids == remote_server_ID:
                    remote_hnswlib_index = remote_hnswlib_indexes[i]
            
            remote_hnswlib_index.set_ef(ef)
            remote_I, remote_D = remote_hnswlib_index.knn_query(q_data, k=k) # I, D are 2-d array

            # merge results
            remote_results = [(remote_D[0][i], remote_server_ID, remote_I[0][i]) for i in range(remote_I.shape[1])]

            results = merge_two_distance_list(local_results, remote_results, k)
        else:
            results = local_plus_cach_results
            
        return results, search_remote

# %%
# def update_methods(instance, HNSW_index):
#     """
#     Update all methods in the instance, 
#         need to manually add all methods below
#     """
#     instance.load_meta_info = HNSW_index.load_meta_info
#     instance.load_ground_layer = HNSW_index.load_ground_layer
#     instance.load_upper_layers = HNSW_index.load_upper_layers
#     instance.insertRemote = HNSW_index.insertRemote
#     instance.searchKnn = HNSW_index.searchKnn
#     instance.searchKnnPlusRemoteCache = HNSW_index.searchKnnPlusRemoteCache
#     instance.searchKnnPlusRemote = HNSW_index.searchKnnPlusRemote
    
def update_methods(instance):
    """
    Update all methods in the instance, 
        need to manually add all methods below
    """
    instance.load_meta_info = HNSW_index.load_meta_info
    instance.load_ground_layer = HNSW_index.load_ground_layer
    instance.load_upper_layers = HNSW_index.load_upper_layers
    instance.insertRemote = HNSW_index.insertRemote
    instance.searchKnn = HNSW_index.searchKnn
    instance.searchKnnPlusRemoteCache = HNSW_index.searchKnnPlusRemoteCache
    instance.searchKnnPlusRemote = HNSW_index.searchKnnPlusRemote

# %% [markdown]
# Links format
#
# bytestrings: 0 0 0 ...
#
# 0 -> no upper layer
# N -> N bytes for the following string, this is m x 4 x (1 + M), here M = 16 ->
#
# 0 0 0 68 {string contents} 0 0 136 {string contents}
#
# string contents: first element: valid edge number; rest: vector IDs
#
# e.g.,
# [
# // first 1 + 16 elements
#   10,
#
#   1561,
#   3999,
#   4373,
#   4213,
#   178,
#   6898,
#   7020,
#   7380,
#   8454,
#   8779,
#   3498,
#   3755,
#   3999,
#   4213,
#   4373,
#   4374,
#
# // second 1 + 16 elements
#   15,
#
#   1191,
#   1298,
#   1311,
#   1781,
#   1930,
#   2086,
#   2598,
#   2925,
#   2936,
#   3262,
#   4374,
#   4390,
#   5441,
#   5546,
#   5607,
#   0],

# %% [markdown]
# ## Example 1: 2 sub-graphs

# %%
from pathlib import Path
index_path='../indexes_subgraph/SIFT1M_index_subgraph_0.bin'#.format(dbname)
data = Path(index_path).read_bytes()
len(data)
# Out:
# 330281768

# %%
hnsw_index = HNSW_index(local_server_ID=0, dim=128)

# %% [markdown]
# The parameters in the index header, stored in small endian
# uint64_t offsetLevel0_; // 0:8
# uint64_t max_elements_; // 8:16
# uint64_t cur_element_count; // 16:24
# uint64_t size_data_per_element_; // 24:32
# uint64_t label_offset_; // 32:40
# uint64_t offsetData_; // 40:48
# uint32_t maxlevel_; // 48:52
# uint32_t enterpoint_node_; // 52:56
# uint64_t maxM_; // 56:64
# uint64_t maxM0_; // 64:72
# uint64_t M_; // 72:80
# double mult_; // 80:88
# uint64_t ef_construction_; // 88:96
#
# Results I got from C++ on SIFT1M:
#
# Index file size: 660564936
# offsetLevel0_: 0
# max_elements_: 1000000
# cur_element_count: 1000000
# size_data_per_element_: 652
# label_offset_: 644
# offsetData_: 132
# maxlevel_: 5
# enterpoint_node_: 572337
# maxM_: 16
# maxM0_: 32
# M_: 16
# mult_: 0.360674
# ef_construction_: 128
#
# size_data_per_element_ 652 = sizeVec (128 * 4) + maxM0_ * link_num (4) size_link_ID (32 * 4) + vec_ID (8)

# %%
hnsw_index.load_meta_info(data)
# Out:
# offsetLevel0_ 0
# max_elements_ 500000
# cur_element_count 500000
# size_data_per_element_ 652
# label_offset_ 644
# offsetData_ 132
# maxlevel_ 4
# enterpoint_node_ 81651
# maxM_ 16
# maxM0_ 32
# M_ 16
# mult_ 0.36067376022224085
# ef_construction_ 128

# %%
# update_methods(hnsw_index, HNSW_index)
t0 = time.time()
HNSW_index.load_ground_layer(hnsw_index, data)
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))
# Out:
# time consumption: 2.47 sec

# %%
# update_methods(hnsw_index, HNSW_index)
t0 = time.time()
HNSW_index.load_upper_layers(hnsw_index, data)
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))
# Out:
# time consumption: 0.74 sec

# %%
# update_methods(hnsw_index, HNSW_index)
t0 = time.time()
result, search_path_local_ID, search_path_vec_ID = HNSW_index.searchKnn(hnsw_index, xq[0], k=1, ef=128) 
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))
# Out:
# time consumption: 0.04 sec

# %%
print(result)
print(gt[0,0])
# Out:
# [[62943.0, 0, 344333]]
# 504814

# %%
print(len(search_path_local_ID), search_path_local_ID)

# %%
print(search_path_vec_ID)

# %%
# sorted_search_path_vec_ID = sorted(list(search_path_vec_ID)) 
# sorted_search_path_local_ID = sorted(list(search_path_local_ID))

# for i in range(len(sorted_search_path_local_ID)):
#     if sorted_search_path_local_ID[i] != sorted_search_path_vec_ID[i]:
#         print("i = {}\tsorted_search_path_local_ID = {}\tsorted_search_path_vec_ID = {}".format(
#             i, sorted_search_path_local_ID[i], sorted_search_path_vec_ID[i]))

# %%
remote_index_path='../indexes_subgraph/SIFT1M_index_subgraph_1.bin'.format(dbname)
remote_hnswlib_index = hnswlib.Index(space='l2', dim=dim)  # the space can be changed - keeps the data, alters the distance function.
print("\nLoading index from {}\n".format(index_path))
remote_hnswlib_index.load_index(remote_index_path)
# Out:
# Loading index from ../indexes_subgraph/SIFT1M_index_subgraph_0.bin

# %%
# update_methods(hnsw_index, HNSW_index)
remote_hnswlib_indexes = [remote_hnswlib_index]
remote_server_IDs = [1]

t0 = time.time()
HNSW_index.insertRemote(hnsw_index, remote_hnswlib_indexes, remote_server_IDs, ef=128)
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))
# Out:
# time consumption: 40.42 sec

# %%
# Search local + remote cache
# update_methods(hnsw_index, HNSW_index)
results, local_results, remote_results, search_remote, remote_server_ID = \
    HNSW_index.searchKnnPlusRemoteCache(hnsw_index, xq[0], k=1, ef=128, all_vectors=xb, debug=True)
# Out:
# level:  4
# current object:  81651 , current distance:  246910.0
# size of neighbors:  5
# cand:  174210 , dist:  249984.0
# cand:  366012 , dist:  275392.0
# cand:  412109 , dist:  249325.0
# cand:  471756 , dist:  336881.0
# cand:  490381 , dist:  227448.0
# changed
# one node finish
#
# current object:  490381 , current distance:  227448.0
# size of neighbors:  5
# cand:  471756 , dist:  336881.0
# cand:  412109 , dist:  249325.0
# cand:  81651 , dist:  246910.0
# cand:  366012 , dist:  275392.0
# cand:  174210 , dist:  249984.0
# one node finish
#
#
# level:  3
# current object:  490381 , current distance:  227448.0
# size of neighbors:  5
# cand:  60604 , dist:  246337.0
# cand:  336884 , dist:  164162.0
# changed
# cand:  83873 , dist:  242739.0
# cand:  359136 , dist:  187997.0
# cand:  38887 , dist:  260823.0
# one node finish
#
# current object:  336884 , current distance:  164162.0
# size of neighbors:  9
# cand:  305846 , dist:  241810.0
# cand:  168474 , dist:  274522.0
# cand:  271720 , dist:  156901.0
# changed
# cand:  233528 , dist:  144910.0
# changed
# cand:  9516 , dist:  245749.0
# cand:  107820 , dist:  178231.0
# cand:  214650 , dist:  191207.0
# cand:  443098 , dist:  181991.0
# cand:  490381 , dist:  227448.0
# one node finish
#
# current object:  233528 , current distance:  144910.0
# size of neighbors:  12
# cand:  390119 , dist:  262204.0
# cand:  101998 , dist:  225613.0
# cand:  392175 , dist:  194620.0
# cand:  67133 , dist:  220379.0
# cand:  149416 , dist:  203152.0
# cand:  428717 , dist:  229376.0
# cand:  91203 , dist:  217426.0
# cand:  429681 , dist:  199556.0
# cand:  190706 , dist:  202020.0
# cand:  289319 , dist:  173736.0
# cand:  443098 , dist:  181991.0
# cand:  210065 , dist:  189080.0
# one node finish
#
#
# level:  2
# current object:  233528 , current distance:  144910.0
# size of neighbors:  16
# cand:  296881 , dist:  205050.0
# cand:  283320 , dist:  142574.0
# changed
# cand:  123006 , dist:  155935.0
# cand:  40289 , dist:  221647.0
# cand:  105807 , dist:  214436.0
# cand:  115235 , dist:  227657.0
# cand:  158000 , dist:  222943.0
# cand:  209378 , dist:  241111.0
# cand:  23190 , dist:  176787.0
# cand:  191078 , dist:  215461.0
# cand:  260638 , dist:  168702.0
# cand:  481802 , dist:  165743.0
# cand:  136576 , dist:  193987.0
# cand:  158373 , dist:  203398.0
# cand:  137990 , dist:  153600.0
# cand:  88972 , dist:  159075.0
# one node finish
#
# current object:  283320 , current distance:  142574.0
# size of neighbors:  16
# cand:  151610 , dist:  161345.0
# cand:  447678 , dist:  172506.0
# cand:  309208 , dist:  218989.0
# cand:  125743 , dist:  181665.0
# cand:  347624 , dist:  191062.0
# cand:  197590 , dist:  185542.0
# cand:  254927 , dist:  184869.0
# cand:  101138 , dist:  189763.0
# cand:  349641 , dist:  176580.0
# cand:  214418 , dist:  180963.0
# cand:  197725 , dist:  166469.0
# cand:  231686 , dist:  163220.0
# cand:  392716 , dist:  179849.0
# cand:  232070 , dist:  150720.0
# cand:  77824 , dist:  160189.0
# cand:  313493 , dist:  106776.0
# changed
# one node finish
#
# current object:  313493 , current distance:  106776.0
# size of neighbors:  16
# cand:  214438 , dist:  173214.0
# cand:  63257 , dist:  172851.0
# cand:  167904 , dist:  156271.0
# cand:  367931 , dist:  189830.0
# cand:  99856 , dist:  159655.0
# cand:  81365 , dist:  151070.0
# cand:  174818 , dist:  167885.0
# cand:  8858 , dist:  159423.0
# cand:  436706 , dist:  156103.0
# cand:  283320 , dist:  142574.0
# cand:  110396 , dist:  174662.0
# cand:  270829 , dist:  162557.0
# cand:  424228 , dist:  117090.0
# cand:  449240 , dist:  201600.0
# cand:  467830 , dist:  170529.0
# cand:  498225 , dist:  165419.0
# one node finish
#
#
# level:  1
# current object:  313493 , current distance:  106776.0
# size of neighbors:  16
# cand:  64920 , dist:  145532.0
# cand:  158672 , dist:  145108.0
# cand:  270829 , dist:  162557.0
# cand:  137132 , dist:  191561.0
# cand:  257671 , dist:  149274.0
# cand:  274303 , dist:  185508.0
# cand:  295874 , dist:  167391.0
# cand:  296110 , dist:  130631.0
# cand:  424228 , dist:  117090.0
# cand:  219044 , dist:  163459.0
# cand:  240953 , dist:  175656.0
# cand:  451181 , dist:  133572.0
# cand:  473069 , dist:  160252.0
# cand:  243910 , dist:  135563.0
# cand:  220601 , dist:  131113.0
# cand:  325418 , dist:  145729.0
# one node finish
#
#
# level: 0
# current object:  313493
# size of neighbors:  30
# current object:  214536 , current distance:  118115.0 , lowerBound:  106776.0
# added
# current object:  99406 , current distance:  145314.0 , lowerBound:  118115.0
# added
# current object:  225825 , current distance:  139662.0 , lowerBound:  145314.0
# added
# current object:  107752 , current distance:  142949.0 , lowerBound:  145314.0
# added
# current object:  67812 , current distance:  145609.0 , lowerBound:  145314.0
# added
# current object:  223861 , current distance:  152512.0 , lowerBound:  145609.0
# added
# current object:  127437 , current distance:  133161.0 , lowerBound:  152512.0
# added
# current object:  194939 , current distance:  154949.0 , lowerBound:  152512.0
# added
# current object:  40688 , current distance:  127326.0 , lowerBound:  154949.0
# added
# current object:  14141 , current distance:  120717.0 , lowerBound:  154949.0
# added
# current object:  159728 , current distance:  123469.0 , lowerBound:  154949.0
# added
# current object:  313492 , current distance:  126153.0 , lowerBound:  154949.0
# added
# current object:  89329 , current distance:  115208.0 , lowerBound:  154949.0
# added
# current object:  261813 , current distance:  121566.0 , lowerBound:  154949.0
# added
# current object:  214983 , current distance:  163403.0 , lowerBound:  154949.0
# added
# current object:  67864 , current distance:  151087.0 , lowerBound:  163403.0
# added
# current object:  314346 , current distance:  117648.0 , lowerBound:  163403.0
# added
# current object:  329662 , current distance:  132874.0 , lowerBound:  163403.0
# added
# current object:  331998 , current distance:  154471.0 , lowerBound:  163403.0
# added
# current object:  344744 , current distance:  160340.0 , lowerBound:  163403.0
# added
# current object:  360844 , current distance:  98057.0 , lowerBound:  163403.0
# added
# current object:  361091 , current distance:  122291.0 , lowerBound:  163403.0
# added
# current object:  412476 , current distance:  154605.0 , lowerBound:  163403.0
# added
# current object:  421241 , current distance:  145927.0 , lowerBound:  163403.0
# added
# current object:  421616 , current distance:  122897.0 , lowerBound:  163403.0
# added
# current object:  422090 , current distance:  146065.0 , lowerBound:  163403.0
# added
# current object:  462634 , current distance:  153233.0 , lowerBound:  163403.0
# added
# current object:  473069 , current distance:  160252.0 , lowerBound:  163403.0
# added
# current object:  482351 , current distance:  113147.0 , lowerBound:  163403.0
# added
# current object:  494005 , current distance:  154395.0 , lowerBound:  163403.0
# added
# one node finishes
#
# current object:  360844
# size of neighbors:  24
# current object:  348314 , current distance:  109469.0 , lowerBound:  163403.0
# added
# current object:  344463 , current distance:  138909.0 , lowerBound:  163403.0
# added
# current object:  140790 , current distance:  150530.0 , lowerBound:  163403.0
# added
# current object:  217698 , current distance:  139582.0 , lowerBound:  163403.0
# added
# current object:  295758 , current distance:  141685.0 , lowerBound:  163403.0
# added
# current object:  180077 , current distance:  131299.0 , lowerBound:  163403.0
# added
# current object:  166667 , current distance:  147285.0 , lowerBound:  163403.0
# added
# current object:  304246 , current distance:  137130.0 , lowerBound:  163403.0
# added
# current object:  313493 , visited already
# current object:  233481 , current distance:  98306.0 , lowerBound:  163403.0
# added
# current object:  350229 , current distance:  144324.0 , lowerBound:  163403.0
# added
# current object:  259725 , current distance:  135439.0 , lowerBound:  163403.0
# added
# current object:  313846 , current distance:  142759.0 , lowerBound:  163403.0
# added
# current object:  39484 , current distance:  135287.0 , lowerBound:  163403.0
# added
# current object:  209122 , current distance:  123046.0 , lowerBound:  163403.0
# added
# current object:  296007 , current distance:  105237.0 , lowerBound:  163403.0
# added
# current object:  377035 , current distance:  134716.0 , lowerBound:  163403.0
# added
# current object:  381450 , current distance:  148026.0 , lowerBound:  163403.0
# added
# current object:  417413 , current distance:  141863.0 , lowerBound:  163403.0
# added
# current object:  422121 , current distance:  116935.0 , lowerBound:  163403.0
# added
# current object:  424228 , current distance:  117090.0 , lowerBound:  163403.0
# added
# current object:  428858 , current distance:  99068.0 , lowerBound:  163403.0
# added
# current object:  475727 , current distance:  188550.0 , lowerBound:  163403.0
# added
# current object:  495905 , current distance:  117296.0 , lowerBound:  188550.0
# added
# one node finishes
#
# current object:  233481
# size of neighbors:  31
# current object:  302318 , current distance:  177134.0 , lowerBound:  188550.0
# added
# current object:  410901 , current distance:  164151.0 , lowerBound:  188550.0
# added
# current object:  313744 , current distance:  153347.0 , lowerBound:  188550.0
# added
# current object:  295688 , current distance:  120762.0 , lowerBound:  188550.0
# added
# current object:  455962 , current distance:  133217.0 , lowerBound:  188550.0
# added
# current object:  359370 , current distance:  131209.0 , lowerBound:  188550.0
# added
# current object:  234260 , current distance:  138067.0 , lowerBound:  188550.0
# added
# current object:  239866 , current distance:  162523.0 , lowerBound:  188550.0
# added
# current object:  259531 , current distance:  144749.0 , lowerBound:  188550.0
# added
# current object:  100722 , current distance:  144463.0 , lowerBound:  188550.0
# added
# current object:  378760 , current distance:  170174.0 , lowerBound:  188550.0
# added
# current object:  233553 , current distance:  139106.0 , lowerBound:  188550.0
# added
# current object:  312999 , current distance:  141918.0 , lowerBound:  188550.0
# added
# current object:  360844 , visited already
# current object:  79659 , current distance:  136831.0 , lowerBound:  188550.0
# added
# current object:  397956 , current distance:  141048.0 , lowerBound:  188550.0
# added
# current object:  104351 , current distance:  132536.0 , lowerBound:  188550.0
# added
# current object:  367571 , current distance:  148982.0 , lowerBound:  188550.0
# added
# current object:  274781 , current distance:  144744.0 , lowerBound:  188550.0
# added
# current object:  107322 , current distance:  147165.0 , lowerBound:  188550.0
# added
# current object:  17400 , current distance:  151307.0 , lowerBound:  188550.0
# added
# current object:  111902 , current distance:  136673.0 , lowerBound:  188550.0
# added
# current object:  5881 , current distance:  148087.0 , lowerBound:  188550.0
# added
# current object:  446430 , current distance:  165674.0 , lowerBound:  188550.0
# added
# current object:  473132 , current distance:  144987.0 , lowerBound:  188550.0
# added
# current object:  416671 , current distance:  132785.0 , lowerBound:  188550.0
# added
# current object:  272693 , current distance:  101360.0 , lowerBound:  188550.0
# added
# current object:  214964 , current distance:  153891.0 , lowerBound:  188550.0
# added
# current object:  233473 , current distance:  130407.0 , lowerBound:  188550.0
# added
# current object:  233941 , current distance:  94540.0 , lowerBound:  188550.0
# added
# current object:  479163 , current distance:  147544.0 , lowerBound:  188550.0
# added
# one node finishes
#
# current object:  233941
# size of neighbors:  32
# current object:  343429 , current distance:  170403.0 , lowerBound:  188550.0
# added
# current object:  268605 , current distance:  138216.0 , lowerBound:  188550.0
# added
# current object:  447153 , current distance:  146999.0 , lowerBound:  188550.0
# added
# current object:  317172 , current distance:  127087.0 , lowerBound:  188550.0
# added
# current object:  330712 , current distance:  114258.0 , lowerBound:  188550.0
# added
# current object:  278921 , current distance:  166155.0 , lowerBound:  188550.0
# added
# current object:  255315 , current distance:  156932.0 , lowerBound:  188550.0
# added
# current object:  122611 , current distance:  170268.0 , lowerBound:  188550.0
# added
# current object:  190431 , current distance:  131072.0 , lowerBound:  188550.0
# added
# current object:  455361 , current distance:  145148.0 , lowerBound:  188550.0
# added
# current object:  37121 , current distance:  133980.0 , lowerBound:  188550.0
# added
# current object:  5962 , current distance:  151665.0 , lowerBound:  188550.0
# added
# current object:  464728 , current distance:  148449.0 , lowerBound:  188550.0
# added
# current object:  229621 , current distance:  148600.0 , lowerBound:  188550.0
# added
# current object:  270967 , current distance:  134738.0 , lowerBound:  188550.0
# added
# current object:  199062 , current distance:  158856.0 , lowerBound:  188550.0
# added
# current object:  458322 , current distance:  144768.0 , lowerBound:  188550.0
# added
# current object:  428088 , current distance:  147755.0 , lowerBound:  188550.0
# added
# current object:  117033 , current distance:  169389.0 , lowerBound:  188550.0
# added
# current object:  370631 , current distance:  128400.0 , lowerBound:  188550.0
# added
# current object:  275804 , current distance:  152944.0 , lowerBound:  188550.0
# added
# current object:  318561 , current distance:  96930.0 , lowerBound:  188550.0
# added
# current object:  152255 , current distance:  162604.0 , lowerBound:  188550.0
# added
# current object:  90902 , current distance:  156187.0 , lowerBound:  188550.0
# added
# current object:  350200 , current distance:  131203.0 , lowerBound:  188550.0
# added
# current object:  358960 , current distance:  152044.0 , lowerBound:  188550.0
# added
# current object:  77860 , current distance:  123519.0 , lowerBound:  188550.0
# added
# current object:  371140 , current distance:  137462.0 , lowerBound:  188550.0
# added
# current object:  233481 , visited already
# current object:  482776 , current distance:  160577.0 , lowerBound:  188550.0
# added
# current object:  483758 , current distance:  124235.0 , lowerBound:  188550.0
# added
# current object:  484685 , current distance:  152590.0 , lowerBound:  188550.0
# added
# one node finishes
#
# current object:  318561
# size of neighbors:  28
# current object:  199690 , current distance:  150624.0 , lowerBound:  188550.0
# added
# current object:  267092 , current distance:  134161.0 , lowerBound:  188550.0
# added
# current object:  302777 , current distance:  136517.0 , lowerBound:  188550.0
# added
# current object:  111957 , current distance:  124385.0 , lowerBound:  188550.0
# added
# current object:  291136 , current distance:  141022.0 , lowerBound:  188550.0
# added
# current object:  188310 , current distance:  155966.0 , lowerBound:  188550.0
# added
# current object:  260404 , current distance:  97008.0 , lowerBound:  188550.0
# added
# current object:  85599 , current distance:  116966.0 , lowerBound:  188550.0
# added
# current object:  217232 , current distance:  160051.0 , lowerBound:  188550.0
# added
# current object:  137816 , current distance:  122004.0 , lowerBound:  188550.0
# added
# current object:  94436 , current distance:  127368.0 , lowerBound:  188550.0
# added
# current object:  87046 , current distance:  164020.0 , lowerBound:  188550.0
# added
# current object:  229070 , current distance:  137016.0 , lowerBound:  188550.0
# added
# current object:  124132 , current distance:  132068.0 , lowerBound:  188550.0
# added
# current object:  233941 , visited already
# current object:  143473 , current distance:  141864.0 , lowerBound:  177134.0
# added
# current object:  333106 , current distance:  147728.0 , lowerBound:  170403.0
# added
# current object:  366948 , current distance:  106116.0 , lowerBound:  170268.0
# added
# current object:  372375 , current distance:  93441.0 , lowerBound:  170174.0
# added
# current object:  378591 , current distance:  149355.0 , lowerBound:  169389.0
# added
# current object:  379535 , current distance:  185552.0 , lowerBound:  166155.0
# current object:  401675 , current distance:  146708.0 , lowerBound:  166155.0
# added
# current object:  427220 , current distance:  132070.0 , lowerBound:  165674.0
# added
# current object:  428038 , current distance:  145859.0 , lowerBound:  164151.0
# added
# current object:  428357 , current distance:  143596.0 , lowerBound:  164020.0
# added
# current object:  428757 , current distance:  133425.0 , lowerBound:  163403.0
# added
# current object:  456019 , current distance:  145343.0 , lowerBound:  162604.0
# added
# current object:  487105 , current distance:  137323.0 , lowerBound:  162523.0
# added
# one node finishes
#
# current object:  372375
# size of neighbors:  22
# current object:  7961 , current distance:  162048.0 , lowerBound:  160577.0
# current object:  111788 , current distance:  132100.0 , lowerBound:  160577.0
# added
# current object:  338309 , current distance:  153858.0 , lowerBound:  160340.0
# added
# current object:  125978 , current distance:  138385.0 , lowerBound:  160252.0
# added
# current object:  7397 , current distance:  101308.0 , lowerBound:  160051.0
# added
# current object:  16259 , current distance:  113856.0 , lowerBound:  158856.0
# added
# current object:  111791 , current distance:  132813.0 , lowerBound:  156932.0
# added
# current object:  137778 , current distance:  147443.0 , lowerBound:  156187.0
# added
# current object:  272907 , current distance:  108925.0 , lowerBound:  155966.0
# added
# current object:  111550 , current distance:  118904.0 , lowerBound:  154949.0
# added
# current object:  47579 , current distance:  119477.0 , lowerBound:  154605.0
# added
# current object:  228845 , current distance:  122234.0 , lowerBound:  154471.0
# added
# current object:  156211 , current distance:  137416.0 , lowerBound:  154395.0
# added
# current object:  318561 , visited already
# current object:  260404 , visited already
# current object:  137859 , current distance:  125281.0 , lowerBound:  153891.0
# added
# current object:  382315 , current distance:  133949.0 , lowerBound:  153858.0
# added
# current object:  383115 , current distance:  184904.0 , lowerBound:  153347.0
# current object:  405651 , current distance:  124657.0 , lowerBound:  153347.0
# added
# current object:  454231 , current distance:  95070.0 , lowerBound:  153233.0
# added
# current object:  459963 , current distance:  143990.0 , lowerBound:  152944.0
# added
# current object:  496424 , current distance:  145791.0 , lowerBound:  152590.0
# added
# one node finishes
#
# current object:  454231
# size of neighbors:  17
# current object:  274326 , current distance:  125096.0 , lowerBound:  152512.0
# added
# current object:  430746 , current distance:  143098.0 , lowerBound:  152044.0
# added
# current object:  187248 , current distance:  161076.0 , lowerBound:  151665.0
# current object:  372427 , current distance:  127123.0 , lowerBound:  151665.0
# added
# current object:  372375 , visited already
# current object:  426954 , current distance:  120602.0 , lowerBound:  151307.0
# added
# current object:  259230 , current distance:  131755.0 , lowerBound:  151087.0
# added
# current object:  75481 , current distance:  104708.0 , lowerBound:  150624.0
# added
# current object:  17095 , current distance:  137701.0 , lowerBound:  150530.0
# added
# current object:  142283 , current distance:  148388.0 , lowerBound:  149355.0
# added
# current object:  65366 , current distance:  129100.0 , lowerBound:  148982.0
# added
# current object:  169968 , current distance:  116717.0 , lowerBound:  148600.0
# added
# current object:  294645 , current distance:  130256.0 , lowerBound:  148449.0
# added
# current object:  337352 , current distance:  132209.0 , lowerBound:  148388.0
# added
# current object:  190828 , current distance:  105687.0 , lowerBound:  148087.0
# added
# current object:  295791 , current distance:  133130.0 , lowerBound:  148026.0
# added
# current object:  454627 , current distance:  144642.0 , lowerBound:  147755.0
# added
# one node finishes
#
# current object:  260404
# size of neighbors:  32
# current object:  487299 , current distance:  146744.0 , lowerBound:  147728.0
# added
# current object:  459554 , current distance:  134685.0 , lowerBound:  147544.0
# added
# current object:  312118 , current distance:  126765.0 , lowerBound:  147443.0
# added
# current object:  367892 , current distance:  155450.0 , lowerBound:  147285.0
# current object:  372375 , visited already
# current object:  384902 , current distance:  113917.0 , lowerBound:  147285.0
# added
# current object:  202624 , current distance:  127568.0 , lowerBound:  147165.0
# added
# current object:  190913 , current distance:  147690.0 , lowerBound:  146999.0
# current object:  426523 , current distance:  148796.0 , lowerBound:  146999.0
# current object:  242771 , current distance:  152648.0 , lowerBound:  146999.0
# current object:  384413 , current distance:  124305.0 , lowerBound:  146999.0
# added
# current object:  311034 , current distance:  126893.0 , lowerBound:  146744.0
# added
# current object:  352923 , current distance:  142312.0 , lowerBound:  146708.0
# added
# current object:  155534 , current distance:  150915.0 , lowerBound:  146065.0
# current object:  382938 , current distance:  141801.0 , lowerBound:  146065.0
# added
# current object:  323026 , current distance:  120970.0 , lowerBound:  145927.0
# added
# current object:  320628 , current distance:  134931.0 , lowerBound:  145859.0
# added
# current object:  191176 , current distance:  107984.0 , lowerBound:  145791.0
# added
# current object:  199521 , current distance:  122142.0 , lowerBound:  145609.0
# added
# current object:  21257 , current distance:  155842.0 , lowerBound:  145343.0
# current object:  199893 , current distance:  138003.0 , lowerBound:  145343.0
# added
# current object:  370414 , current distance:  130795.0 , lowerBound:  145314.0
# added
# current object:  347085 , current distance:  127844.0 , lowerBound:  145148.0
# added
# current object:  124439 , current distance:  129908.0 , lowerBound:  144987.0
# added
# current object:  311862 , current distance:  139504.0 , lowerBound:  144768.0
# added
# current object:  481457 , current distance:  109679.0 , lowerBound:  144749.0
# added
# current object:  268937 , current distance:  128884.0 , lowerBound:  144744.0
# added
# current object:  486885 , current distance:  106016.0 , lowerBound:  144642.0
# added
# current object:  416530 , current distance:  126307.0 , lowerBound:  144463.0
# added
# current object:  395566 , current distance:  134886.0 , lowerBound:  144324.0
# added
# current object:  488084 , current distance:  137967.0 , lowerBound:  143990.0
# added
# current object:  138612 , current distance:  138260.0 , lowerBound:  143596.0
# added
# one node finishes
#
# current object:  428858
# size of neighbors:  22
# current object:  44732 , current distance:  141067.0 , lowerBound:  143098.0
# added
# current object:  123167 , current distance:  114839.0 , lowerBound:  142949.0
# added
# current object:  312790 , current distance:  121944.0 , lowerBound:  142759.0
# added
# current object:  133064 , current distance:  140926.0 , lowerBound:  142312.0
# added
# current object:  337581 , current distance:  172275.0 , lowerBound:  141918.0
# current object:  318484 , current distance:  115969.0 , lowerBound:  141918.0
# added
# current object:  5880 , current distance:  126481.0 , lowerBound:  141864.0
# added
# current object:  175133 , current distance:  140080.0 , lowerBound:  141863.0
# added
# current object:  191064 , current distance:  101864.0 , lowerBound:  141801.0
# added
# current object:  348314 , visited already
# current object:  360844 , visited already
# current object:  22487 , current distance:  111117.0 , lowerBound:  141685.0
# added
# current object:  425939 , current distance:  112281.0 , lowerBound:  141067.0
# added
# current object:  40683 , current distance:  122439.0 , lowerBound:  141048.0
# added
# current object:  187719 , current distance:  122161.0 , lowerBound:  141022.0
# added
# current object:  182953 , current distance:  139969.0 , lowerBound:  140926.0
# added
# current object:  454695 , current distance:  156187.0 , lowerBound:  140080.0
# current object:  455064 , current distance:  144729.0 , lowerBound:  140080.0
# current object:  456643 , current distance:  108890.0 , lowerBound:  140080.0
# added
# current object:  458344 , current distance:  121018.0 , lowerBound:  139969.0
# added
# current object:  481333 , current distance:  141443.0 , lowerBound:  139662.0
# current object:  495777 , current distance:  149577.0 , lowerBound:  139662.0
# one node finishes
#
# current object:  7397
# size of neighbors:  32
# current object:  24593 , current distance:  161223.0 , lowerBound:  139662.0
# current object:  296346 , current distance:  106156.0 , lowerBound:  139662.0
# added
# current object:  23465 , current distance:  148535.0 , lowerBound:  139582.0
# current object:  313711 , current distance:  156854.0 , lowerBound:  139582.0
# current object:  323124 , current distance:  121488.0 , lowerBound:  139582.0
# added
# current object:  161983 , current distance:  134652.0 , lowerBound:  139504.0
# added
# current object:  63599 , current distance:  172315.0 , lowerBound:  139106.0
# current object:  171151 , current distance:  165925.0 , lowerBound:  139106.0
# current object:  108824 , current distance:  151807.0 , lowerBound:  139106.0
# current object:  71358 , current distance:  125422.0 , lowerBound:  139106.0
# added
# current object:  107856 , current distance:  142935.0 , lowerBound:  138909.0
# current object:  308593 , current distance:  156409.0 , lowerBound:  138909.0
# current object:  133171 , current distance:  87341.0 , lowerBound:  138909.0
# added
# current object:  41039 , current distance:  116034.0 , lowerBound:  138385.0
# added
# current object:  205737 , current distance:  122176.0 , lowerBound:  138260.0
# added
# current object:  34367 , current distance:  165504.0 , lowerBound:  138216.0
# current object:  302000 , current distance:  151863.0 , lowerBound:  138216.0
# current object:  18058 , current distance:  139327.0 , lowerBound:  138216.0
# current object:  391492 , current distance:  131160.0 , lowerBound:  138216.0
# added
# current object:  107881 , current distance:  108831.0 , lowerBound:  138067.0
# added
# current object:  199755 , current distance:  142056.0 , lowerBound:  138003.0
# current object:  295907 , current distance:  126705.0 , lowerBound:  138003.0
# added
# current object:  173545 , current distance:  154071.0 , lowerBound:  137967.0
# current object:  157360 , current distance:  160747.0 , lowerBound:  137967.0
# current object:  34372 , current distance:  124779.0 , lowerBound:  137967.0
# added
# current object:  83241 , current distance:  121232.0 , lowerBound:  137701.0
# added
# current object:  127223 , current distance:  127928.0 , lowerBound:  137462.0
# added
# current object:  363325 , current distance:  125874.0 , lowerBound:  137416.0
# added
# current object:  18347 , current distance:  152568.0 , lowerBound:  137323.0
# current object:  192058 , current distance:  166391.0 , lowerBound:  137323.0
# current object:  127366 , current distance:  148497.0 , lowerBound:  137323.0
# current object:  482899 , current distance:  116797.0 , lowerBound:  137323.0
# added
# one node finishes
#
# current object:  133171
# size of neighbors:  32
# current object:  67984 , current distance:  124275.0 , lowerBound:  137130.0
# added
# current object:  128317 , current distance:  158296.0 , lowerBound:  137016.0
# current object:  367783 , current distance:  174092.0 , lowerBound:  137016.0
# current object:  295688 , visited already
# current object:  274326 , visited already
# current object:  126826 , current distance:  99912.0 , lowerBound:  137016.0
# added
# current object:  392776 , current distance:  145035.0 , lowerBound:  136831.0
# current object:  446541 , current distance:  161435.0 , lowerBound:  136831.0
# current object:  192725 , current distance:  137501.0 , lowerBound:  136831.0
# current object:  425146 , current distance:  146602.0 , lowerBound:  136831.0
# current object:  144238 , current distance:  137376.0 , lowerBound:  136831.0
# current object:  313705 , current distance:  107150.0 , lowerBound:  136831.0
# added
# current object:  233030 , current distance:  121526.0 , lowerBound:  136673.0
# added
# current object:  295663 , current distance:  154158.0 , lowerBound:  136517.0
# current object:  133103 , current distance:  123973.0 , lowerBound:  136517.0
# added
# current object:  370339 , current distance:  143344.0 , lowerBound:  135439.0
# current object:  155765 , current distance:  138433.0 , lowerBound:  135439.0
# current object:  185008 , current distance:  137427.0 , lowerBound:  135439.0
# current object:  64 , current distance:  130285.0 , lowerBound:  135439.0
# added
# current object:  4976 , current distance:  174248.0 , lowerBound:  135287.0
# current object:  89590 , current distance:  107619.0 , lowerBound:  135287.0
# added
# current object:  454876 , current distance:  140668.0 , lowerBound:  134931.0
# current object:  344318 , current distance:  130597.0 , lowerBound:  134931.0
# added
# current object:  183643 , current distance:  96188.0 , lowerBound:  134886.0
# added
# current object:  321123 , current distance:  143346.0 , lowerBound:  134738.0
# current object:  156670 , current distance:  150613.0 , lowerBound:  134738.0
# current object:  187730 , current distance:  160452.0 , lowerBound:  134738.0
# current object:  370481 , current distance:  101068.0 , lowerBound:  134738.0
# added
# current object:  253780 , current distance:  141483.0 , lowerBound:  134716.0
# current object:  7397 , visited already
# current object:  133137 , current distance:  127433.0 , lowerBound:  134716.0
# added
# current object:  99770 , current distance:  131058.0 , lowerBound:  134685.0
# added
# one node finishes
#
# current object:  183643
# size of neighbors:  29
# current object:  263978 , current distance:  158696.0 , lowerBound:  134652.0
# current object:  128281 , current distance:  115565.0 , lowerBound:  134652.0
# added
# current object:  23047 , current distance:  117026.0 , lowerBound:  134161.0
# added
# current object:  123596 , current distance:  163353.0 , lowerBound:  133980.0
# current object:  232646 , current distance:  174180.0 , lowerBound:  133980.0
# current object:  144635 , current distance:  127046.0 , lowerBound:  133980.0
# added
# current object:  393412 , current distance:  112943.0 , lowerBound:  133949.0
# added
# current object:  123001 , current distance:  150205.0 , lowerBound:  133425.0
# current object:  122596 , current distance:  131552.0 , lowerBound:  133425.0
# added
# current object:  23390 , current distance:  129802.0 , lowerBound:  133217.0
# added
# current object:  64914 , current distance:  140351.0 , lowerBound:  133161.0
# current object:  299608 , current distance:  145893.0 , lowerBound:  133161.0
# current object:  261220 , current distance:  138854.0 , lowerBound:  133161.0
# current object:  196813 , current distance:  153196.0 , lowerBound:  133161.0
# current object:  346701 , current distance:  111118.0 , lowerBound:  133161.0
# added
# current object:  61299 , current distance:  140960.0 , lowerBound:  133130.0
# current object:  379347 , current distance:  113319.0 , lowerBound:  133130.0
# added
# current object:  202214 , current distance:  143863.0 , lowerBound:  132874.0
# current object:  106905 , current distance:  133544.0 , lowerBound:  132874.0
# current object:  183486 , current distance:  114249.0 , lowerBound:  132874.0
# added
# current object:  133171 , visited already
# current object:  439039 , current distance:  130071.0 , lowerBound:  132813.0
# added
# current object:  260419 , current distance:  119270.0 , lowerBound:  132785.0
# added
# current object:  387920 , current distance:  149697.0 , lowerBound:  132536.0
# current object:  183264 , current distance:  106671.0 , lowerBound:  132536.0
# added
# current object:  107376 , current distance:  132653.0 , lowerBound:  132209.0
# current object:  449681 , current distance:  103659.0 , lowerBound:  132209.0
# added
# current object:  476069 , current distance:  157258.0 , lowerBound:  132100.0
# current object:  495520 , current distance:  115715.0 , lowerBound:  132100.0
# added
# one node finishes
#
# current object:  126826
# size of neighbors:  30
# current object:  149267 , current distance:  160471.0 , lowerBound:  132070.0
# current object:  217710 , current distance:  112235.0 , lowerBound:  132070.0
# added
# current object:  221597 , current distance:  156442.0 , lowerBound:  132068.0
# current object:  370215 , current distance:  139996.0 , lowerBound:  132068.0
# current object:  47517 , current distance:  165999.0 , lowerBound:  132068.0
# current object:  133171 , visited already
# current object:  170489 , current distance:  159638.0 , lowerBound:  132068.0
# current object:  111163 , current distance:  152531.0 , lowerBound:  132068.0
# current object:  270558 , current distance:  174961.0 , lowerBound:  132068.0
# current object:  150261 , current distance:  170006.0 , lowerBound:  132068.0
# current object:  93648 , current distance:  158195.0 , lowerBound:  132068.0
# current object:  93205 , current distance:  156080.0 , lowerBound:  132068.0
# current object:  60687 , current distance:  110261.0 , lowerBound:  132068.0
# added
# current object:  45919 , current distance:  110962.0 , lowerBound:  131755.0
# added
# current object:  276019 , current distance:  116354.0 , lowerBound:  131552.0
# added
# current object:  107665 , current distance:  149429.0 , lowerBound:  131299.0
# current object:  281550 , current distance:  172984.0 , lowerBound:  131299.0
# current object:  334273 , current distance:  170866.0 , lowerBound:  131299.0
# current object:  156436 , current distance:  180689.0 , lowerBound:  131299.0
# current object:  234224 , current distance:  140939.0 , lowerBound:  131299.0
# current object:  314111 , current distance:  127370.0 , lowerBound:  131299.0
# added
# current object:  240861 , current distance:  126948.0 , lowerBound:  131209.0
# added
# current object:  293957 , current distance:  152023.0 , lowerBound:  131203.0
# current object:  127020 , current distance:  132100.0 , lowerBound:  131203.0
# current object:  210142 , current distance:  124199.0 , lowerBound:  131203.0
# added
# current object:  16367 , current distance:  102602.0 , lowerBound:  131160.0
# added
# current object:  373799 , current distance:  157377.0 , lowerBound:  131072.0
# current object:  383791 , current distance:  136417.0 , lowerBound:  131072.0
# current object:  429527 , current distance:  129816.0 , lowerBound:  131072.0
# added
# current object:  458642 , current distance:  119742.0 , lowerBound:  131058.0
# added
# one node finishes
#
# current object:  370481
# size of neighbors:  23
# current object:  24172 , current distance:  160399.0 , lowerBound:  130795.0
# current object:  57078 , current distance:  151499.0 , lowerBound:  130795.0
# current object:  136373 , current distance:  144336.0 , lowerBound:  130795.0
# current object:  57506 , current distance:  133003.0 , lowerBound:  130795.0
# current object:  335953 , current distance:  100768.0 , lowerBound:  130795.0
# added
# current object:  293029 , current distance:  159161.0 , lowerBound:  130597.0
# current object:  227797 , current distance:  113732.0 , lowerBound:  130597.0
# added
# current object:  105482 , current distance:  160757.0 , lowerBound:  130407.0
# current object:  294957 , current distance:  116266.0 , lowerBound:  130407.0
# added
# current object:  94607 , current distance:  156885.0 , lowerBound:  130285.0
# current object:  127155 , current distance:  161253.0 , lowerBound:  130285.0
# current object:  152884 , current distance:  166032.0 , lowerBound:  130285.0
# current object:  133171 , visited already
# current object:  122259 , current distance:  124786.0 , lowerBound:  130285.0
# added
# current object:  289816 , current distance:  150699.0 , lowerBound:  130256.0
# current object:  370372 , current distance:  116833.0 , lowerBound:  130256.0
# added
# current object:  370496 , current distance:  112252.0 , lowerBound:  130071.0
# added
# current object:  371262 , current distance:  117493.0 , lowerBound:  129908.0
# added
# current object:  371424 , current distance:  114159.0 , lowerBound:  129816.0
# added
# current object:  375991 , current distance:  140364.0 , lowerBound:  129802.0
# current object:  428901 , current distance:  138024.0 , lowerBound:  129802.0
# current object:  440779 , current distance:  137071.0 , lowerBound:  129802.0
# current object:  452680 , current distance:  152005.0 , lowerBound:  129802.0
# one node finishes
#
# current object:  335953
# size of neighbors:  25
# current object:  272907 , visited already
# current object:  144238 , visited already
# current object:  138560 , current distance:  118273.0 , lowerBound:  129802.0
# added
# current object:  227984 , current distance:  125062.0 , lowerBound:  129100.0
# added
# current object:  292528 , current distance:  184535.0 , lowerBound:  128884.0
# current object:  22951 , current distance:  119882.0 , lowerBound:  128884.0
# added
# current object:  185209 , current distance:  126599.0 , lowerBound:  128400.0
# added
# current object:  179069 , current distance:  129668.0 , lowerBound:  127928.0
# current object:  126723 , current distance:  141099.0 , lowerBound:  127928.0
# current object:  315152 , current distance:  143504.0 , lowerBound:  127928.0
# current object:  209549 , current distance:  147462.0 , lowerBound:  127928.0
# current object:  136485 , current distance:  154907.0 , lowerBound:  127928.0
# current object:  8084 , current distance:  144328.0 , lowerBound:  127928.0
# current object:  257918 , current distance:  150868.0 , lowerBound:  127928.0
# current object:  106133 , current distance:  142441.0 , lowerBound:  127928.0
# current object:  124029 , current distance:  115979.0 , lowerBound:  127928.0
# added
# current object:  354935 , current distance:  168253.0 , lowerBound:  127844.0
# current object:  370481 , visited already
# current object:  370626 , current distance:  117543.0 , lowerBound:  127844.0
# added
# current object:  373730 , current distance:  145633.0 , lowerBound:  127568.0
# current object:  413101 , current distance:  122621.0 , lowerBound:  127568.0
# added
# current object:  435736 , current distance:  125728.0 , lowerBound:  127433.0
# added
# current object:  449681 , visited already
# current object:  455633 , current distance:  166226.0 , lowerBound:  127370.0
# current object:  468314 , current distance:  129684.0 , lowerBound:  127370.0
# one node finishes
#
# current object:  272693
# size of neighbors:  31
# current object:  392791 , current distance:  175058.0 , lowerBound:  127370.0
# current object:  294493 , current distance:  136053.0 , lowerBound:  127370.0
# current object:  428901 , visited already
# current object:  426828 , current distance:  144293.0 , lowerBound:  127370.0
# current object:  318480 , current distance:  153890.0 , lowerBound:  127370.0
# current object:  457179 , current distance:  131842.0 , lowerBound:  127370.0
# current object:  338343 , current distance:  151061.0 , lowerBound:  127370.0
# current object:  370106 , current distance:  121743.0 , lowerBound:  127370.0
# added
# current object:  318484 , visited already
# current object:  301139 , current distance:  100386.0 , lowerBound:  127368.0
# added
# current object:  383467 , current distance:  146667.0 , lowerBound:  127326.0
# current object:  74033 , current distance:  102323.0 , lowerBound:  127326.0
# added
# current object:  46234 , current distance:  116071.0 , lowerBound:  127123.0
# added
# current object:  246723 , current distance:  157701.0 , lowerBound:  127087.0
# current object:  232448 , current distance:  131233.0 , lowerBound:  127087.0
# current object:  7989 , current distance:  123094.0 , lowerBound:  127087.0
# added
# current object:  468112 , current distance:  156686.0 , lowerBound:  127046.0
# current object:  61537 , current distance:  144348.0 , lowerBound:  127046.0
# current object:  126810 , current distance:  121665.0 , lowerBound:  127046.0
# added
# current object:  285035 , current distance:  111719.0 , lowerBound:  126948.0
# added
# current object:  44276 , current distance:  165615.0 , lowerBound:  126893.0
# current object:  441988 , current distance:  156282.0 , lowerBound:  126893.0
# current object:  480913 , current distance:  167997.0 , lowerBound:  126893.0
# current object:  233481 , visited already
# current object:  368627 , current distance:  135344.0 , lowerBound:  126893.0
# current object:  358066 , current distance:  117163.0 , lowerBound:  126893.0
# added
# current object:  422483 , current distance:  101956.0 , lowerBound:  126765.0
# added
# current object:  126902 , current distance:  134694.0 , lowerBound:  126705.0
# current object:  486862 , current distance:  134568.0 , lowerBound:  126705.0
# current object:  493673 , current distance:  136301.0 , lowerBound:  126705.0
# current object:  498984 , current distance:  127222.0 , lowerBound:  126705.0
# one node finishes
#
# current object:  301139
# size of neighbors:  26
# current object:  166667 , visited already
# current object:  22937 , current distance:  117787.0 , lowerBound:  126705.0
# added
# current object:  13059 , current distance:  138904.0 , lowerBound:  126599.0
# current object:  14141 , visited already
# current object:  128892 , current distance:  184308.0 , lowerBound:  126599.0
# current object:  288708 , current distance:  109162.0 , lowerBound:  126599.0
# added
# current object:  221333 , current distance:  131943.0 , lowerBound:  126481.0
# current object:  172076 , current distance:  150792.0 , lowerBound:  126481.0
# current object:  247879 , current distance:  151603.0 , lowerBound:  126481.0
# current object:  186787 , current distance:  133586.0 , lowerBound:  126481.0
# current object:  41281 , current distance:  127624.0 , lowerBound:  126481.0
# current object:  229591 , current distance:  114698.0 , lowerBound:  126481.0
# added
# current object:  195924 , current distance:  165353.0 , lowerBound:  126307.0
# current object:  272693 , visited already
# current object:  82778 , current distance:  133522.0 , lowerBound:  126307.0
# current object:  92776 , current distance:  103471.0 , lowerBound:  126307.0
# added
# current object:  317171 , current distance:  163002.0 , lowerBound:  126153.0
# current object:  317297 , current distance:  155152.0 , lowerBound:  126153.0
# current object:  326503 , current distance:  201039.0 , lowerBound:  126153.0
# current object:  335562 , current distance:  139486.0 , lowerBound:  126153.0
# current object:  344381 , current distance:  142720.0 , lowerBound:  126153.0
# current object:  344473 , current distance:  95919.0 , lowerBound:  126153.0
# added
# current object:  421488 , current distance:  132633.0 , lowerBound:  125874.0
# current object:  459465 , current distance:  140334.0 , lowerBound:  125874.0
# current object:  465384 , current distance:  153631.0 , lowerBound:  125874.0
# current object:  488992 , current distance:  153087.0 , lowerBound:  125874.0
# one node finishes
#
# current object:  344473
# size of neighbors:  21
# current object:  278818 , current distance:  80082.0 , lowerBound:  125874.0
# added
# current object:  233931 , current distance:  130035.0 , lowerBound:  125728.0
# current object:  183530 , current distance:  138873.0 , lowerBound:  125728.0
# current object:  180431 , current distance:  119394.0 , lowerBound:  125728.0
# added
# current object:  126884 , current distance:  124644.0 , lowerBound:  125422.0
# added
# current object:  15643 , current distance:  150097.0 , lowerBound:  125281.0
# current object:  333865 , current distance:  122611.0 , lowerBound:  125281.0
# added
# current object:  163783 , current distance:  123562.0 , lowerBound:  125096.0
# added
# current object:  272844 , current distance:  153279.0 , lowerBound:  125062.0
# current object:  274316 , current distance:  179191.0 , lowerBound:  125062.0
# current object:  76458 , current distance:  114970.0 , lowerBound:  125062.0
# added
# current object:  277578 , current distance:  135137.0 , lowerBound:  124786.0
# current object:  314314 , current distance:  143792.0 , lowerBound:  124786.0
# current object:  301139 , visited already
# current object:  22937 , visited already
# current object:  192692 , current distance:  132938.0 , lowerBound:  124786.0
# current object:  400311 , current distance:  146696.0 , lowerBound:  124786.0
# current object:  404728 , current distance:  195259.0 , lowerBound:  124786.0
# current object:  456643 , visited already
# current object:  456970 , current distance:  120582.0 , lowerBound:  124786.0
# added
# current object:  459020 , current distance:  130076.0 , lowerBound:  124779.0
# one node finishes
#
# current object:  278818
# size of neighbors:  30
# current object:  443300 , current distance:  170080.0 , lowerBound:  124779.0
# current object:  335812 , current distance:  195151.0 , lowerBound:  124779.0
# current object:  314570 , current distance:  142769.0 , lowerBound:  124779.0
# current object:  431172 , current distance:  132750.0 , lowerBound:  124779.0
# current object:  326072 , current distance:  138424.0 , lowerBound:  124779.0
# current object:  316321 , current distance:  128714.0 , lowerBound:  124779.0
# current object:  462533 , current distance:  183099.0 , lowerBound:  124779.0
# current object:  374215 , current distance:  143306.0 , lowerBound:  124779.0
# current object:  384233 , current distance:  140948.0 , lowerBound:  124779.0
# current object:  155876 , current distance:  143122.0 , lowerBound:  124779.0
# current object:  231022 , current distance:  144900.0 , lowerBound:  124779.0
# current object:  185209 , visited already
# current object:  344473 , visited already
# current object:  370682 , current distance:  112914.0 , lowerBound:  124779.0
# added
# current object:  173562 , current distance:  159300.0 , lowerBound:  124657.0
# current object:  26679 , current distance:  139302.0 , lowerBound:  124657.0
# current object:  233052 , current distance:  113891.0 , lowerBound:  124657.0
# added
# current object:  459664 , current distance:  111107.0 , lowerBound:  124644.0
# added
# current object:  108040 , current distance:  103984.0 , lowerBound:  124385.0
# added
# current object:  372062 , current distance:  123436.0 , lowerBound:  124305.0
# added
# current object:  191176 , visited already
# current object:  362142 , current distance:  124806.0 , lowerBound:  124275.0
# current object:  262130 , current distance:  148472.0 , lowerBound:  124275.0
# current object:  425974 , current distance:  132847.0 , lowerBound:  124275.0
# current object:  401812 , current distance:  133035.0 , lowerBound:  124275.0
# current object:  458526 , current distance:  144352.0 , lowerBound:  124275.0
# current object:  111957 , visited already
# current object:  12676 , current distance:  131083.0 , lowerBound:  124275.0
# current object:  470052 , current distance:  178351.0 , lowerBound:  124275.0
# current object:  485562 , current distance:  127727.0 , lowerBound:  124275.0
# one node finishes
#
# current object:  191064
# size of neighbors:  27
# current object:  384816 , current distance:  178370.0 , lowerBound:  124275.0
# current object:  246289 , current distance:  158091.0 , lowerBound:  124275.0
# current object:  296200 , current distance:  165457.0 , lowerBound:  124275.0
# current object:  213306 , current distance:  171899.0 , lowerBound:  124275.0
# current object:  191982 , current distance:  170815.0 , lowerBound:  124275.0
# current object:  337057 , current distance:  135286.0 , lowerBound:  124275.0
# current object:  454226 , current distance:  145949.0 , lowerBound:  124275.0
# current object:  312844 , current distance:  159738.0 , lowerBound:  124275.0
# current object:  99285 , current distance:  135720.0 , lowerBound:  124275.0
# current object:  341992 , current distance:  124869.0 , lowerBound:  124275.0
# current object:  171420 , current distance:  155472.0 , lowerBound:  124275.0
# current object:  49095 , current distance:  157780.0 , lowerBound:  124275.0
# current object:  125096 , current distance:  126893.0 , lowerBound:  124275.0
# current object:  180707 , current distance:  138572.0 , lowerBound:  124275.0
# current object:  141857 , current distance:  139036.0 , lowerBound:  124275.0
# current object:  53698 , current distance:  123005.0 , lowerBound:  124275.0
# added
# current object:  65221 , current distance:  156327.0 , lowerBound:  124235.0
# current object:  321496 , current distance:  162424.0 , lowerBound:  124235.0
# current object:  45919 , visited already
# current object:  76458 , visited already
# current object:  84857 , current distance:  147014.0 , lowerBound:  124235.0
# current object:  162253 , current distance:  123194.0 , lowerBound:  124235.0
# added
# current object:  428858 , visited already
# ...
# current object:  189170 , current distance:  156286.0 , lowerBound:  107984.0
# current object:  191594 , current distance:  142713.0 , lowerBound:  107984.0
# current object:  272415 , current distance:  154814.0 , lowerBound:  107984.0
# current object:  36011 , visited already
# current object:  228002 , visited already
# current object:  24502 , current distance:  145172.0 , lowerBound:  107984.0
# current object:  155915 , current distance:  140595.0 , lowerBound:  107984.0
# current object:  105503 , current distance:  151602.0 , lowerBound:  107984.0
# current object:  310715 , current distance:  176099.0 , lowerBound:  107984.0
# current object:  233060 , current distance:  137999.0 , lowerBound:  107984.0
# current object:  52717 , visited already
# current object:  35879 , current distance:  134884.0 , lowerBound:  107984.0
# current object:  271558 , current distance:  147728.0 , lowerBound:  107984.0
# current object:  380219 , current distance:  108800.0 , lowerBound:  107984.0
# current object:  423247 , current distance:  151567.0 , lowerBound:  107984.0
# current object:  456011 , current distance:  178987.0 , lowerBound:  107984.0
# current object:  497429 , current distance:  159066.0 , lowerBound:  107984.0
# one node finishes
#
# current object:  486856
# size of neighbors:  18
# current object:  376178 , current distance:  150882.0 , lowerBound:  107984.0
# current object:  52815 , current distance:  122547.0 , lowerBound:  107984.0
# current object:  185860 , current distance:  161790.0 , lowerBound:  107984.0
# current object:  68142 , current distance:  156233.0 , lowerBound:  107984.0
# current object:  58379 , current distance:  135328.0 , lowerBound:  107984.0
# current object:  77829 , current distance:  141161.0 , lowerBound:  107984.0
# current object:  422884 , current distance:  179591.0 , lowerBound:  107984.0
# current object:  391971 , current distance:  122617.0 , lowerBound:  107984.0
# current object:  386523 , current distance:  130035.0 , lowerBound:  107984.0
# current object:  100324 , current distance:  121043.0 , lowerBound:  107984.0
# current object:  364502 , current distance:  129924.0 , lowerBound:  107984.0
# current object:  445351 , current distance:  156448.0 , lowerBound:  107984.0
# current object:  110693 , current distance:  155025.0 , lowerBound:  107984.0
# current object:  76361 , visited already
# current object:  100277 , visited already
# current object:  143779 , current distance:  137613.0 , lowerBound:  107984.0
# current object:  486896 , current distance:  131895.0 , lowerBound:  107984.0
# current object:  487027 , current distance:  142080.0 , lowerBound:  107984.0
# one node finishes
#
# current object:  89590
# size of neighbors:  24
# current object:  254512 , current distance:  171893.0 , lowerBound:  107984.0
# current object:  313743 , current distance:  168240.0 , lowerBound:  107984.0
# current object:  90339 , current distance:  144660.0 , lowerBound:  107984.0
# current object:  18046 , visited already
# current object:  5949 , current distance:  141557.0 , lowerBound:  107984.0
# current object:  88073 , current distance:  192280.0 , lowerBound:  107984.0
# current object:  68204 , current distance:  144525.0 , lowerBound:  107984.0
# current object:  247826 , current distance:  141118.0 , lowerBound:  107984.0
# current object:  57728 , current distance:  127626.0 , lowerBound:  107984.0
# current object:  123048 , current distance:  138605.0 , lowerBound:  107984.0
# current object:  173170 , current distance:  133103.0 , lowerBound:  107984.0
# current object:  55635 , current distance:  163020.0 , lowerBound:  107984.0
# current object:  133171 , visited already
# current object:  88401 , current distance:  132086.0 , lowerBound:  107984.0
# current object:  22487 , visited already
# current object:  39393 , current distance:  149352.0 , lowerBound:  107984.0
# current object:  239650 , visited already
# current object:  314467 , current distance:  144692.0 , lowerBound:  107984.0
# current object:  313042 , current distance:  154280.0 , lowerBound:  107984.0
# current object:  313152 , current distance:  140039.0 , lowerBound:  107984.0
# current object:  313955 , current distance:  143479.0 , lowerBound:  107984.0
# current object:  89330 , visited already
# current object:  323253 , visited already
# current object:  440330 , visited already
# one node finishes
#
# current object:  296383
# size of neighbors:  12
# current object:  296321 , visited already
# current object:  9682 , current distance:  140745.0 , lowerBound:  107984.0
# current object:  167538 , current distance:  155400.0 , lowerBound:  107984.0
# current object:  139291 , current distance:  155139.0 , lowerBound:  107984.0
# current object:  174819 , current distance:  150653.0 , lowerBound:  107984.0
# current object:  219536 , visited already
# current object:  272336 , visited already
# current object:  296497 , visited already
# current object:  324138 , current distance:  158521.0 , lowerBound:  107984.0
# current object:  344333 , visited already
# current object:  357557 , current distance:  125481.0 , lowerBound:  107984.0
# current object:  493681 , visited already
# one node finishes
#
# current object:  295657
# size of neighbors:  26
# current object:  71358 , visited already
# current object:  122512 , current distance:  125798.0 , lowerBound:  107984.0
# current object:  88401 , visited already
# current object:  214463 , current distance:  147237.0 , lowerBound:  107984.0
# current object:  76709 , current distance:  157890.0 , lowerBound:  107984.0
# current object:  107634 , current distance:  139244.0 , lowerBound:  107984.0
# current object:  293662 , current distance:  122489.0 , lowerBound:  107984.0
# current object:  60687 , visited already
# current object:  77724 , visited already
# current object:  122183 , current distance:  159517.0 , lowerBound:  107984.0
# current object:  139283 , visited already
# current object:  234116 , current distance:  149421.0 , lowerBound:  107984.0
# current object:  77859 , current distance:  139551.0 , lowerBound:  107984.0
# current object:  238444 , visited already
# current object:  272098 , visited already
# current object:  77897 , visited already
# current object:  295762 , current distance:  162535.0 , lowerBound:  107984.0
# current object:  296256 , visited already
# current object:  296793 , current distance:  127833.0 , lowerBound:  107984.0
# current object:  332040 , visited already
# current object:  372211 , current distance:  172199.0 , lowerBound:  107984.0
# current object:  380352 , current distance:  160284.0 , lowerBound:  107984.0
# current object:  415369 , current distance:  159125.0 , lowerBound:  107984.0
# current object:  450851 , visited already
# current object:  492059 , current distance:  145108.0 , lowerBound:  107984.0
# current object:  494527 , current distance:  147308.0 , lowerBound:  107984.0
# one node finishes
#
# current object:  146660
# size of neighbors:  31
# current object:  203804 , current distance:  186924.0 , lowerBound:  107984.0
# current object:  160546 , current distance:  172002.0 , lowerBound:  107984.0
# current object:  393274 , current distance:  121749.0 , lowerBound:  107984.0
# current object:  402375 , current distance:  133600.0 , lowerBound:  107984.0
# current object:  156052 , current distance:  144221.0 , lowerBound:  107984.0
# current object:  124367 , current distance:  185138.0 , lowerBound:  107984.0
# current object:  124426 , current distance:  131728.0 , lowerBound:  107984.0
# current object:  282849 , visited already
# current object:  302383 , current distance:  178043.0 , lowerBound:  107984.0
# current object:  87738 , current distance:  136418.0 , lowerBound:  107984.0
# current object:  311045 , current distance:  124985.0 , lowerBound:  107984.0
# current object:  123146 , current distance:  138102.0 , lowerBound:  107984.0
# current object:  37956 , visited already
# current object:  152690 , current distance:  130089.0 , lowerBound:  107984.0
# current object:  309068 , current distance:  176693.0 , lowerBound:  107984.0
# current object:  328980 , visited already
# current object:  77702 , visited already
# current object:  240390 , current distance:  147618.0 , lowerBound:  107984.0
# current object:  61486 , current distance:  141977.0 , lowerBound:  107984.0
# current object:  110579 , current distance:  153185.0 , lowerBound:  107984.0
# current object:  40683 , visited already
# current object:  216130 , visited already
# current object:  133111 , current distance:  136264.0 , lowerBound:  107984.0
# current object:  255590 , current distance:  146770.0 , lowerBound:  107984.0
# current object:  193204 , current distance:  142340.0 , lowerBound:  107984.0
# current object:  23303 , current distance:  163897.0 , lowerBound:  107984.0
# current object:  311022 , current distance:  115883.0 , lowerBound:  107984.0
# current object:  292756 , visited already
# current object:  426779 , current distance:  146059.0 , lowerBound:  107984.0
# current object:  482463 , current distance:  130578.0 , lowerBound:  107984.0
# current object:  495220 , current distance:  153631.0 , lowerBound:  107984.0
# one node finishes
#
# current object:  191176
# size of neighbors:  32
# current object:  370397 , current distance:  151336.0 , lowerBound:  107984.0
# current object:  467221 , current distance:  148001.0 , lowerBound:  107984.0
# current object:  278818 , visited already
# current object:  209386 , visited already
# current object:  229077 , current distance:  103100.0 , lowerBound:  107984.0
# added
# current object:  201947 , current distance:  149681.0 , lowerBound:  107906.0
# current object:  188465 , visited already
# current object:  318716 , current distance:  141094.0 , lowerBound:  107906.0
# current object:  21513 , current distance:  160249.0 , lowerBound:  107906.0
# current object:  23960 , current distance:  152725.0 , lowerBound:  107906.0
# current object:  45373 , current distance:  169447.0 , lowerBound:  107906.0
# current object:  121996 , current distance:  124535.0 , lowerBound:  107906.0
# current object:  209239 , current distance:  138607.0 , lowerBound:  107906.0
# current object:  190673 , visited already
# current object:  124860 , visited already
# current object:  275737 , current distance:  118090.0 , lowerBound:  107906.0
# current object:  428980 , current distance:  128807.0 , lowerBound:  107906.0
# current object:  260404 , visited already
# current object:  429583 , current distance:  133814.0 , lowerBound:  107906.0
# current object:  46234 , visited already
# current object:  110352 , current distance:  148629.0 , lowerBound:  107906.0
# current object:  382479 , current distance:  141768.0 , lowerBound:  107906.0
# current object:  438720 , current distance:  151344.0 , lowerBound:  107906.0
# current object:  358141 , visited already
# current object:  429802 , visited already
# current object:  201958 , current distance:  132602.0 , lowerBound:  107906.0
# current object:  26009 , current distance:  154930.0 , lowerBound:  107906.0
# current object:  105403 , current distance:  148520.0 , lowerBound:  107906.0
# current object:  336344 , current distance:  138010.0 , lowerBound:  107906.0
# current object:  57223 , current distance:  149546.0 , lowerBound:  107906.0
# current object:  483228 , current distance:  173601.0 , lowerBound:  107906.0
# current object:  495798 , visited already
# one node finishes
#
# current object:  229077
# size of neighbors:  30
# current object:  87097 , current distance:  143673.0 , lowerBound:  107906.0
# current object:  62022 , current distance:  140426.0 , lowerBound:  107906.0
# current object:  61461 , current distance:  130410.0 , lowerBound:  107906.0
# current object:  115803 , current distance:  122363.0 , lowerBound:  107906.0
# current object:  155487 , current distance:  120282.0 , lowerBound:  107906.0
# current object:  46474 , current distance:  145392.0 , lowerBound:  107906.0
# current object:  11325 , current distance:  168627.0 , lowerBound:  107906.0
# current object:  86427 , current distance:  142509.0 , lowerBound:  107906.0
# current object:  52717 , visited already
# current object:  228785 , current distance:  118991.0 , lowerBound:  107906.0
# current object:  134977 , current distance:  149212.0 , lowerBound:  107906.0
# current object:  160475 , current distance:  146404.0 , lowerBound:  107906.0
# current object:  61674 , current distance:  165324.0 , lowerBound:  107906.0
# current object:  191176 , visited already
# current object:  170311 , current distance:  158780.0 , lowerBound:  107906.0
# current object:  228719 , current distance:  120407.0 , lowerBound:  107906.0
# current object:  252268 , current distance:  178255.0 , lowerBound:  107906.0
# current object:  259467 , current distance:  136732.0 , lowerBound:  107906.0
# current object:  269882 , current distance:  137030.0 , lowerBound:  107906.0
# current object:  271338 , current distance:  105242.0 , lowerBound:  107906.0
# added
# current object:  290721 , current distance:  134513.0 , lowerBound:  107815.0
# current object:  339647 , current distance:  143593.0 , lowerBound:  107815.0
# current object:  340284 , current distance:  137069.0 , lowerBound:  107815.0
# current object:  363684 , current distance:  120640.0 , lowerBound:  107815.0
# current object:  372391 , current distance:  133757.0 , lowerBound:  107815.0
# current object:  403181 , current distance:  123370.0 , lowerBound:  107815.0
# current object:  411475 , current distance:  139103.0 , lowerBound:  107815.0
# current object:  429648 , current distance:  126073.0 , lowerBound:  107815.0
# current object:  433110 , current distance:  161176.0 , lowerBound:  107815.0
# current object:  458875 , current distance:  173680.0 , lowerBound:  107815.0
# one node finishes
#
# current object:  271338
# size of neighbors:  32
# current object:  165254 , current distance:  155259.0 , lowerBound:  107815.0
# current object:  228876 , current distance:  159884.0 , lowerBound:  107815.0
# current object:  192732 , current distance:  138508.0 , lowerBound:  107815.0
# current object:  53222 , current distance:  122680.0 , lowerBound:  107815.0
# current object:  229077 , visited already
# current object:  138399 , current distance:  131325.0 , lowerBound:  107815.0
# current object:  103882 , current distance:  160638.0 , lowerBound:  107815.0
# current object:  133090 , current distance:  127220.0 , lowerBound:  107815.0
# current object:  125485 , current distance:  169020.0 , lowerBound:  107815.0
# current object:  153911 , current distance:  130367.0 , lowerBound:  107815.0
# current object:  260404 , visited already
# current object:  123254 , current distance:  133342.0 , lowerBound:  107815.0
# current object:  17522 , current distance:  175404.0 , lowerBound:  107815.0
# current object:  93641 , current distance:  147522.0 , lowerBound:  107815.0
# current object:  5974 , current distance:  142134.0 , lowerBound:  107815.0
# current object:  19856 , current distance:  158673.0 , lowerBound:  107815.0
# current object:  272394 , current distance:  123475.0 , lowerBound:  107815.0
# current object:  300324 , current distance:  171618.0 , lowerBound:  107815.0
# current object:  313365 , current distance:  135614.0 , lowerBound:  107815.0
# current object:  341405 , current distance:  157731.0 , lowerBound:  107815.0
# current object:  341637 , current distance:  152850.0 , lowerBound:  107815.0
# current object:  362990 , current distance:  163169.0 , lowerBound:  107815.0
# current object:  370402 , current distance:  115785.0 , lowerBound:  107815.0
# current object:  372969 , current distance:  172318.0 , lowerBound:  107815.0
# current object:  373764 , visited already
# current object:  395648 , current distance:  152411.0 , lowerBound:  107815.0
# current object:  419707 , visited already
# current object:  438214 , current distance:  146600.0 , lowerBound:  107815.0
# current object:  442341 , current distance:  176840.0 , lowerBound:  107815.0
# current object:  444858 , current distance:  156359.0 , lowerBound:  107815.0
# current object:  457071 , current distance:  154295.0 , lowerBound:  107815.0
# current object:  466299 , current distance:  138181.0 , lowerBound:  107815.0
# one node finishes

# %%
print(search_remote)
# Out:
# True

# %%
print(results)
print(local_results)
print(remote_results)
print(gt[0][0])
# Out:
# [(61125.0, 1, 504814)]
# [[62943.0, 0, 344333]]
# [(61125.0, 1, 504814)]
# 504814

# %%
result_list = []
search_remote_list = []
query_num = 10000

for i in range(query_num):
    results, local_results, remote_results, search_remote = HNSW_index.searchKnnPlusRemoteCache(hnsw_index, xq[i], k=1, ef=128, all_vectors=xb, debug=False)
    result_list.append(results[-1])
    search_remote_list.append(search_remote)

# %%
## Get recall for consider up to 1 remote hop
## Wenqi comment: even just 1 hop can reach 97% recall!!!
# First 100 queries -> 0.97 recall
# First 1000 queries -> 0.990 recall
# First 10000 queries -> 0.9949 recall (visit remote graph = 0.9978)

count = 0
for i in range(query_num):
    ID = result_list[i][2]
    if ID == gt[i][0]: count += 1
print(count/query_num, count)

# %%
# Count how many searches travel to remote node

search_remote_count = 0
for i in range(query_num):
    if search_remote_list[i]: search_remote_count += 1
print(search_remote_count/query_num, search_remote_count)

# %%
# Search local + remote when needed
# update_methods(hnsw_index, HNSW_index)
remote_hnswlib_indexes = [remote_hnswlib_index]
remote_server_IDs = [1]

HNSW_index.searchKnnPlusRemote(
    hnsw_index, xq[0], k=10, ef=128, all_vectors=xb, 
    remote_hnswlib_indexes=remote_hnswlib_indexes, remote_server_IDs=remote_server_IDs, debug=False)
# Out:
# ([(61125.0, 1, 504814),
#   (62943.0, 0, 344333),
#   (73660.0, 1, 900184),
#   (77284.0, 1, 657385),
#   (77515.0, 0, 205768),
#   (80082.0, 0, 278818),
#   (82498.0, 1, 831624),
#   (83564.0, 1, 885651),
#   (84903.0, 1, 504835),
#   (85222.0, 1, 504547)],
#  True)

# %%
result_list = []
search_remote_list = []
query_num = 100

for i in range(query_num):
    results, search_remote = HNSW_index.searchKnnPlusRemote(
        hnsw_index, xq[i], k=1, ef=128, all_vectors=xb, 
        remote_hnswlib_indexes=remote_hnswlib_indexes, remote_server_IDs=remote_server_IDs, debug=False)
    result_list.append(results[-1])
    search_remote_list.append(search_remote)

# %%
## Get recall for local + remote
## for first 100 queries; 1 hop can reach 97%; lazy evaluation search all = 98% recall (maybe good partitioning can solve it?)
# First 1000 queries -> 0.993 recall
# First 10000 queries -> 0.9978 -> Very high, should be high enough, so lazy evaluation should work well!

count = 0
for i in range(query_num):
    ID = result_list[i][2]
    if ID == gt[i][0]: count += 1
print(count/query_num, count)
# Out:
# 0.98 98

# %%
# Count how many searches travel to remote node
# for 10000 queris, 50.19% of search travels to the other server

search_remote_count = 0
for i in range(query_num):
    if search_remote_list[i]: search_remote_count += 1
print(search_remote_count/query_num, search_remote_count)
