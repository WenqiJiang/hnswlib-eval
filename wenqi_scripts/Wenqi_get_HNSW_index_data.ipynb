# %%
import hnswlib
import numpy as np 
import struct
import heapq
import time

# %%
def mmap_fvecs(fname):
    x = np.memmap(fname, dtype='int32', mode='r')
    d = x[0]
    return x.view('float32').reshape(-1, d + 1)[:, 1:]

def mmap_bvecs(fname):
    x = np.memmap(fname, dtype='uint8', mode='r')
    d = x[:4].view('int32')[0]
    return x.reshape(-1, d + 4)[:, 4:]

def ivecs_read(fname):
    a = np.fromfile(fname, dtype='int32')
    d = a[0]
    # Wenqi: Format of ground truth (for 10000 query vectors):
    #   1000(topK), [1000 ids]
    #   1000(topK), [1000 ids]
    #        ...     ...
    #   1000(topK), [1000 ids]
    # 10000 rows in total, 10000 * 1001 elements, 10000 * 1001 * 4 bytes
    return a.reshape(-1, d + 1)[:, 1:].copy()

def fvecs_read(fname):
    return ivecs_read(fname).view('float32')

# %%
dbname = 'SIFT1M'
index_path='../indexes/{}_index.bin'.format(dbname)
dim=128

if dbname.startswith('SIFT'):
    # SIFT1M to SIFT1000M
    dbsize = int(dbname[4:-1])
    xb = mmap_bvecs('/mnt/scratch/wenqi/Faiss_experiments/bigann/bigann_base.bvecs')
    xq = mmap_bvecs('/mnt/scratch/wenqi/Faiss_experiments/bigann/bigann_query.bvecs')
    gt = ivecs_read('/mnt/scratch/wenqi/Faiss_experiments/bigann/gnd/idx_%dM.ivecs' % dbsize)

    N_VEC = int(dbsize * 1000 * 1000)

    # trim xb to correct size
    xb = xb[:dbsize * 1000 * 1000]

    # Wenqi: load xq to main memory and reshape
    xq = xq.astype('float32').copy()
    xq = np.array(xq, dtype=np.float32)
    gt = np.array(gt, dtype=np.int32)

    print("Vector shapes:")
    print("Base vector xb: ", xb.shape)
    print("Query vector xq: ", xq.shape)
    print("Ground truth gt: ", gt.shape)
else:
    print('unknown dataset', dbname, file=sys.stderr)
    sys.exit(1)
# Out:
# Vector shapes:
# Base vector xb:  (1000000, 128)
# Query vector xq:  (10000, 128)
# Ground truth gt:  (10000, 1000)

# %% [markdown]
# ## Core HNSW load and search

# %%
def convertBytes(bytestring, dtype='int'):
    """
    convert bytes to a single element
    dtype = {int, long, float, double}
    struct: https://docs.python.org/3/library/struct.html
    """ 
    # int from bytes is much faster than struct.unpack
    if dtype =='int' or dtype == 'long': 
        return int.from_bytes(bytestring, byteorder='little', signed=False)
    elif dtype == 'float': 
        return struct.unpack('f', bytestring)[0]
    elif dtype == 'double': 
        return struct.unpack('d', bytestring)[0]
    else:
        raise ValueError 

# Wenqi: the fastest way to load a bytestring list is to use *** np.frombuffer ***
def convertBytesList(bytestring, dtype='int'):
    """
    Given a byte string, return the value list
    """
    result_list = []
    if dtype == 'int' or dtype == 'float':
        dsize = 4
    elif dtype == 'long' or dtype == 'double':
        dsize = 8
    else:
        raise ValueError 
        
    start_pointer = 0
    for i in range(len(bytestring) // dsize):
        result_list.append(convertBytes(
            bytestring[start_pointer: start_pointer + dsize], dtype=dtype))
        start_pointer += dsize
    return result_list

def calculateDist(query_data, db_vec):
    """
    HNSWLib returns L2 square distance, so do we
        both inputs are 1-d np array
    """
    # return l2 distance between two points
    return np.sum((query_data - db_vec) ** 2)


def merge_two_distance_list(list_A, list_B, k):
    """
    merge two lists by selecting the k pairs of the smallest distance
    input:
        both list has format [(dist, ID), (dist, ID), ...]
    return:
        a result list, with ascending distance (the first contains the largest distance)
    """
    
    results_heap = []
    for i in range(len(list_A)):
        dist, server_ID, vec_ID = list_A[i]
        heapq.heappush(results_heap, (-dist, server_ID, vec_ID))
    for i in range(len(list_B)):
        dist, server_ID, vec_ID = list_B[i]
        heapq.heappush(results_heap, (-dist, server_ID, vec_ID))

    while len(results_heap) > k:
        heapq.heappop(results_heap)

    results = []
    while len(results_heap) > 0:
        dist, server_ID, vec_ID = results_heap[0]
        results.append((-dist, server_ID, vec_ID))
        heapq.heappop(results_heap)
    results.reverse()
            
    return results

# %%
import struct 

        
class HNSW_index():
    
    """
    Returned result list always in the format of (dist, server_ID, vec_ID),
        in ascending distance order (the first result is the nearest neighbor)
    """
    
    def __init__(self, local_server_ID=0, dim=128):
        
        self.dim = dim
        self.local_server_ID = local_server_ID
        
        # Meta Info
        self.offsetLevel0_ = None
        self.max_elements_ = None
        self.cur_element_count = None
        self.size_data_per_element_ = None
        self.label_offset_ = None
        self.offsetData_ = None
        self.maxlevel_ = None
        self.enterpoint_node_ = None
        self.maxM_ = None
        self.maxM0_ = None
        self.M_ = None
        self.mult_ = None # the probability that a node is one a higher level
        self.ef_construction_ = None
        
        # ground layer, all with length of cur_element_count
        self.links_count_l0 = None # a list of link_count
        self.links_l0 = None # a list of links per vector
        self.data_l0 = None # a list of vectors
        label_l0 = None # a list of vector IDs
        
        # upper layers, all with length of cur_element_count
        self.element_levels_ = None # the level per vector
        self.links = None # the upper layer link info (link count + links)
        
        # remote nodes, order according to local ID (not label ID)
        #  remote_links: an 2-D array (cur_element_count, k), 
        #    each element is a tuple: (server_ID, vector_ID)
        self.remote_links_count = None
        self.remote_links = None
        
    def load_meta_info(self, index_bin):
        """
        index_bin = hnswlib index binary 
        
        HNSW save index order:
            https://github.com/WenqiJiang/hnswlib-eval/blob/master/hnswlib/hnswalg.h#L588-L616
        """
        self.offsetLevel0_ = int.from_bytes(index_bin[0:8], byteorder='little', signed=False)
        self.max_elements_ = int.from_bytes(index_bin[8:16], byteorder='little', signed=False)
        self.cur_element_count = int.from_bytes(index_bin[16:24], byteorder='little', signed=False)
        self.size_data_per_element_ = int.from_bytes(index_bin[24:32], byteorder='little', signed=False)
        self.label_offset_ = int.from_bytes(index_bin[32:40], byteorder='little', signed=False)
        self.offsetData_ = int.from_bytes(index_bin[40:48], byteorder='little', signed=False)
        self.maxlevel_ = int.from_bytes(index_bin[48:52], byteorder='little', signed=False)
        self.enterpoint_node_ = int.from_bytes(index_bin[52:56], byteorder='little', signed=False)
        self.maxM_ = int.from_bytes(index_bin[56:64], byteorder='little', signed=False)
        self.maxM0_ = int.from_bytes(index_bin[64:72], byteorder='little', signed=False)
        self.M_ = int.from_bytes(index_bin[72:80], byteorder='little', signed=False)
        self.mult_ = struct.unpack('d', index_bin[80:88])[0] # the probability that a node is one a higher level
        self.ef_construction_ = int.from_bytes(index_bin[88:96], byteorder='little', signed=False)
        

        print("offsetLevel0_", self.offsetLevel0_)
        print("max_elements_", self.max_elements_)
        print("cur_element_count", self.cur_element_count)
        print("size_data_per_element_", self.size_data_per_element_)
        print("label_offset_", self.label_offset_)
        print("offsetData_", self.offsetData_)
        print("maxlevel_", self.maxlevel_)
        print("enterpoint_node_", self.enterpoint_node_)
        print("maxM_", self.maxM_)
        print("maxM0_", self.maxM0_)
        print("M_", self.M_)
        print("mult_", self.mult_)
        print("ef_construction_", self.ef_construction_)
        
    
    def load_ground_layer(self, index_bin):
        """
        Get the ground layer vector ID, vectors, and links:
            links_count_l0: vec_num
            links_l0: maxM0_ * vec_num 
            data_l0: (dim, vec_num)
            label_l0: vec_num
        """
        
        # Layer 0 data 
        start_byte_pointer = 96
        delta = self.cur_element_count * self.size_data_per_element_
        data_level0 = index_bin[start_byte_pointer: start_byte_pointer + delta]
        
        size = len(data_level0)
        self.links_count_l0 = []
        self.links_l0 = np.zeros((self.cur_element_count, self.maxM0_), dtype=int)
        self.data_l0 = np.zeros((self.cur_element_count, self.dim))
        self.label_l0 = []

        data_l0_list = []
        
        assert len(data_level0) == self.size_data_per_element_ * self.cur_element_count
        
        size_link_count = 4
        size_links = self.maxM0_ * 4
        size_vectors = self.dim * 4
        size_label = 8
        
        assert self.size_data_per_element_ == \
            size_link_count + size_links + size_vectors + size_label
            
        for i in range(self.cur_element_count):
            # per ground layer node: (link_count (int), links (int array of len=maxM0_), 
            #    vector (float array of len=dim, vector ID (long)))
            
            addr_link_count = i * self.size_data_per_element_ 
            addr_links = addr_link_count + size_link_count
            addr_vectors = addr_links + size_links
            addr_label = addr_vectors + size_vectors
            
            tmp_bytes = data_level0[addr_link_count: addr_link_count + size_link_count]
            self.links_count_l0.append(convertBytes(tmp_bytes, dtype='int'))
        
            tmp_bytes = data_level0[addr_links: addr_links + size_links]
            self.links_l0[i] = np.frombuffer(tmp_bytes, dtype=np.int32)
            
            tmp_bytes = data_level0[addr_vectors: addr_vectors + size_vectors]
            self.data_l0[i] = np.frombuffer(tmp_bytes, dtype=np.float32)
            
            tmp_bytes = data_level0[addr_label: addr_label + size_label]
            self.label_l0.append(convertBytes(tmp_bytes, dtype='long'))


    def load_upper_layers(self, index_bin):
        """
        Get the upper layer info:
            element_levels_: the levels of each vector
            links: list of upper links
        """
        
        # meta + ground data
        start_byte_pointer = 96 + self.max_elements_ * self.size_data_per_element_
        
        # Upper layers
        links_count = 0
        size_links_per_element_ = self.maxM_ * 4 + 4
        self.element_levels_ = []
        self.links = []

        for i in range(self.cur_element_count):
            tmp_bytes = index_bin[start_byte_pointer:start_byte_pointer+4]
            linkListSize = convertBytes(tmp_bytes, dtype='int')
            start_byte_pointer += 4
            
            # if an element is only on ground layer, it has no links on upper layers at all
            if linkListSize == 0:
                self.element_levels_.append(0)
                self.links.append([])
            else:
                level = int(linkListSize / size_links_per_element_)
                self.element_levels_.append(level)
                tmp_bytes = index_bin[start_byte_pointer:start_byte_pointer+linkListSize]
                links_tmp = list(np.frombuffer(tmp_bytes, dtype=np.int32))
                start_byte_pointer += linkListSize
                links_count += linkListSize / 4;
                self.links.append(links_tmp)

        assert start_byte_pointer == len(index_bin) # 6606296

    def insertRemote(self, remote_hnswlib_indexes, remote_server_IDs, ef=128):
        """
        Input: 
            remote_hnswlib_indexes: a list of remote_hnswlib_index
                remote_hnswlib_index: index loaded by remote memory (hnswlib object)
            remote_server_IDs: a list of remote index IDs respective to remote_hnswlib_indexes
                e.g., this is server 1, and there are four servers in totol,
                    then the remote index IDs should be [0, 2, 3]
        """
        self.remote_links_count = []
        self.remote_links = []
        
        remote_I_list = []
        remote_D_list = []
        remote_server_ID_list = []
        
        k = self.maxM0_
        
        assert len(remote_hnswlib_indexes) == len(remote_server_IDs)
        
        # query all servers
        for i in range(len(remote_server_IDs)):
            remote_hnswlib_index = remote_hnswlib_indexes[i]
            remote_server_ID = remote_server_IDs[i]
        
            query = self.data_l0
            remote_hnswlib_index.set_ef(ef)
            I, D = remote_hnswlib_index.knn_query(query, k=k)
            remote_I_list.append(I)
            remote_D_list.append(D)
            remote_server_ID_list.append(
                np.ones((I.shape[0], I.shape[1]), dtype=np.int32) * int(remote_server_ID))
    
        # merge results per server
        remote_I = np.concatenate(remote_I_list, axis=1)
        remote_D = np.concatenate(remote_D_list, axis=1)
        remote_server_ID = np.concatenate(remote_server_ID_list, axis=1)
        
        D_server_ID_I_list = [[] for i in range(remote_I.shape[0])]
        server_ID_I_list= [[] for i in range(remote_I.shape[0])]
        for i in range(remote_I.shape[0]):
            for j in range(remote_I.shape[1]):
                D_server_ID_I_list[i].append((remote_D[i][j], remote_server_ID[i][j], remote_I[i][j]))
            D_server_ID_I_list[i].sort()
            D_server_ID_I_list[i] = D_server_ID_I_list[i][:k]
            server_ID_I_list[i] = [(s, i) for d, s, i in D_server_ID_I_list[i]]
                
        
        self.remote_links_count = [k for i in range(self.cur_element_count)]
        #  remote_links: an 2-D array (cur_element_count x k), 
        #    each element is a tuple: (server_ID, vector_ID)
        self.remote_links = server_ID_I_list
        

    def searchKnn(self, q_data, k, ef, debug=False):
        """
        result a list of (distance, vec_ID) in ascending distance
        """
        
        ep_node = self.enterpoint_node_
        num_elements = self.cur_element_count
        max_level = self.maxlevel_
        links_count_l0 = self.links_count_l0
        links_l0 = self.links_l0
        data_l0 = self.data_l0
        links = self.links
        label_l0 = self.label_l0
        dim = self.dim
        
        currObj = ep_node
        currVec = data_l0[currObj]
        curdist = calculateDist(q_data, currVec)
        
        search_path_local_ID = set()
        search_path_vec_ID = set()
        
        # search upper layers
        for level in reversed(range(1, max_level+1)):
            if debug:
                print("")
                print("level: ", level)
            changed = True
            while changed:
                if debug:
                    print("current object: ", currObj, ", current distance: ", curdist)
                search_path_local_ID.add(currObj)
                changed = False
                ### Wenqi: here, assuming Node ID can be used to retrieve upper links (which is not true for indexes with ID starting from non-0)
                if (len(links[currObj])==0):
                    break
                else:
                    start_index = (level-1) * 17
                    size = links[currObj][start_index]
                    if debug:
                        print("size of neighbors: ", size) 
                    neighbors = links[currObj][(start_index+1):(start_index+17)]
                    for i in range(size):
                        cand = neighbors[i]
                        currVec = data_l0[cand]
                        dist = calculateDist(q_data, currVec)
                        if debug:
                            print("cand: ", cand, ", dist: ", dist)
                        if (dist < curdist):
                            curdist = dist
                            currObj = cand
                            changed = True
                            if debug:
                                print("changed")
                    if debug:
                        print("one node finish")
                        print("")

        # search in ground layer
        if debug:
            print("")
            print("level: 0")
        visited_array = set() # default 0
        top_candidates = []
        candidate_set = []
        lowerBound = curdist 
        # By default heap queue is a min heap: https://docs.python.org/3/library/heapq.html
        # candidate_set = candidate list, min heap
        # top_candidates = dynamic list (potential results), max heap
        # compare min(candidate_set) vs max(top_candidates)
        heapq.heappush(top_candidates, (-curdist, currObj))
        heapq.heappush(candidate_set,(curdist, currObj))
        visited_array.add(currObj) 

        while len(candidate_set)!=0:
            current_node_pair = candidate_set[0]
            if ((current_node_pair[0] > lowerBound)):
                break
            heapq.heappop(candidate_set)
            current_node_id = current_node_pair[1]
            search_path_local_ID.add(current_node_id)
            size = links_count_l0[current_node_id]
            if debug:
                print("current object: ", current_node_id)
                print("size of neighbors: ", size)
            for i in range(size):
                candidate_id = links_l0[current_node_id][i]
                if (candidate_id not in visited_array):
                    visited_array.add(candidate_id)
                    currVec = data_l0[candidate_id]
                    dist = calculateDist(q_data, currVec)
                    if debug:
                        print("current object: ", candidate_id, ", current distance: ", dist, ", lowerBound: ", lowerBound)
                    if (len(top_candidates) < ef or lowerBound > dist):
                        if debug:
                            print("added")
                        heapq.heappush(candidate_set, (dist, candidate_id))
                        heapq.heappush(top_candidates, (-dist, candidate_id))
                    if (len(top_candidates) > ef):
                        heapq.heappop(top_candidates)
                    if (len(top_candidates)!=0):
                        lowerBound = -top_candidates[0][0]
                else :
                    if debug:
                        print("current object: ", candidate_id, ", visited already")
            if debug:
                print("one node finishes")
                print("")

        while len(top_candidates) > k:
            heapq.heappop(top_candidates)

        result = []
        while len(top_candidates) > 0:
            candidate_pair = top_candidates[0]
            # Wenqi: here, replace the local candidate ID by real node ID, great!
            result.append([-candidate_pair[0], self.local_server_ID, label_l0[candidate_pair[1]]])
            heapq.heappop(top_candidates)
        result.reverse()
            
        for local_ID in search_path_local_ID:
            search_path_vec_ID.add(label_l0[local_ID])

        return result, search_path_local_ID, search_path_vec_ID
        
    def searchKnnPlusRemoteCache(self, q_data, k, ef, all_vectors, debug=False):
        """
        Seach local vectors + cached remote vectors
        Input: 
            all vectors = the entire dataset with N_TOTAL d-dimensional vectors, used to do remote search
        Output:
            a list of local results, in asending distance
            a list of remote results (only with the vectors one hop away from local), in asending distance
            a list of merged results, in asending distance
            whether one should search remote (True/False)
        """
        local_results, search_path_local_ID, search_path_vec_ID = self.searchKnn(q_data, k, ef, debug=debug)
        # get the list of remote vectors that should be visited
        remote_server_ID_vec_ID_list = []
        
        for local_ID in search_path_local_ID:
            link_count = self.remote_links_count[local_ID]
            for i in range(link_count):
                remote_server_ID_vec_ID_list.append(self.remote_links[local_ID][i])
    
        remote_results_heap = []
        for remote_server_ID, vec_ID in remote_server_ID_vec_ID_list:
            dist = np.sum((q_data - all_vectors[vec_ID]) ** 2)
            heapq.heappush(remote_results_heap, (-dist, remote_server_ID, vec_ID))
            
        while len(remote_results_heap) > k:
            heapq.heappop(remote_results_heap)

        remote_results = []
        while len(remote_results_heap) > 0:
            dist, remote_server_ID, vec_ID = remote_results_heap[0]
            remote_results.append((-dist, remote_server_ID, vec_ID))
            heapq.heappop(remote_results_heap)
        remote_results.reverse()
            
        # Merge local + remote
        results = merge_two_distance_list(local_results, remote_results, k)
            
        if remote_results[0][0] < local_results[0][0]:
            search_remote = True
            remote_server_ID = remote_results[0][1]
        else:
            search_remote = False
            remote_server_ID = -1
            
        return results, local_results, remote_results, search_remote, remote_server_ID
        

        
    def searchKnnPlusRemote(self, q_data, k, ef, all_vectors, remote_hnswlib_indexes, remote_server_IDs, debug=False):
        """
        Search local vectors, hop to remote index ***(currently only support 1 index)*** when needed
            *** Thus, this is only a testing functino, in reality, there should be a global search 
                function allowing multiple hops between servers ***
        Input: 
            all vectors = the entire dataset with N_TOTAL d-dimensional vectors, used to do remote search
            remote_hnswlib_indexes: a list of remote_hnswlib_index
                remote_hnswlib_index: index loaded by remote memory (hnswlib object)
            remote_server_IDs: a list of remote index IDs respective to remote_hnswlib_indexes
                e.g., this is server 1, and there are four servers in totol,
                    then the remote index IDs should be [0, 2, 3]
        Output:
            a list of local results, in distance ascending order
            a list of remote results (only with the vectors one hop away from local)
            a list of merged results
            whether one should search remote (True/False)
        """
        local_plus_cach_results, local_results, remote_results, search_remote, remote_server_ID = \
            self.searchKnnPlusRemoteCache(q_data, k, ef, all_vectors, debug=debug)
        
        if search_remote:
            for i, ids in enumerate(remote_server_IDs):
                if ids == remote_server_ID:
                    remote_hnswlib_index = remote_hnswlib_indexes[i]
            
            remote_hnswlib_index.set_ef(ef)
            remote_I, remote_D = remote_hnswlib_index.knn_query(q_data, k=k) # I, D are 2-d array

            # merge results
            remote_results = [(remote_D[0][i], remote_server_ID, remote_I[0][i]) for i in range(remote_I.shape[1])]

            results = merge_two_distance_list(local_results, remote_results, k)
        else:
            results = local_plus_cach_results
            
        return results, search_remote

# %% [markdown]
# Links format
#
# bytestrings: 0 0 0 ...
#
# 0 -> no upper layer
# N -> N bytes for the following string, this is m x 4 x (1 + M), here M = 16 ->
#
# 0 0 0 68 {string contents} 0 0 136 {string contents}
#
# string contents: first element: valid edge number; rest: vector IDs
#
# e.g.,
# [
# // first 1 + 16 elements
#   10,
#
#   1561,
#   3999,
#   4373,
#   4213,
#   178,
#   6898,
#   7020,
#   7380,
#   8454,
#   8779,
#   3498,
#   3755,
#   3999,
#   4213,
#   4373,
#   4374,
#
# // second 1 + 16 elements
#   15,
#
#   1191,
#   1298,
#   1311,
#   1781,
#   1930,
#   2086,
#   2598,
#   2925,
#   2936,
#   3262,
#   4374,
#   4390,
#   5441,
#   5546,
#   5607,
#   0],

# %% [markdown]
# ## Example 1: 2 sub-graphs

# %%
from pathlib import Path
index_path='../indexes_subgraph/SIFT1M_index_subgraph_0.bin'#.format(dbname)
index = Path(index_path).read_bytes()
len(index)

# %%
hnsw_index = HNSW_index(local_server_ID=0, dim=128)

# %% [markdown]
# The parameters in the index header, stored in small endian
# uint64_t offsetLevel0_; // 0:8
# uint64_t max_elements_; // 8:16
# uint64_t cur_element_count; // 16:24
# uint64_t size_data_per_element_; // 24:32
# uint64_t label_offset_; // 32:40
# uint64_t offsetData_; // 40:48
# uint32_t maxlevel_; // 48:52
# uint32_t enterpoint_node_; // 52:56
# uint64_t maxM_; // 56:64
# uint64_t maxM0_; // 64:72
# uint64_t M_; // 72:80
# double mult_; // 80:88
# uint64_t ef_construction_; // 88:96
#
# Results I got from C++ on SIFT1M:
#
# Index file size: 660564936
# offsetLevel0_: 0
# max_elements_: 1000000
# cur_element_count: 1000000
# size_data_per_element_: 652
# label_offset_: 644
# offsetData_: 132
# maxlevel_: 5
# enterpoint_node_: 572337
# maxM_: 16
# maxM0_: 32
# M_: 16
# mult_: 0.360674
# ef_construction_: 128
#
# size_data_per_element_ 652 = sizeVec (128 * 4) + maxM0_ * link_num (4) size_link_ID (32 * 4) + vec_ID (8)

# %%
hnsw_index.load_meta_info(index)

# %%
t0 = time.time()
HNSW_index.load_ground_layer(hnsw_index, index)
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))

# %%
t0 = time.time()
HNSW_index.load_upper_layers(hnsw_index, index)
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))

# %%
t0 = time.time()
result, search_path_local_ID, search_path_vec_ID = HNSW_index.searchKnn(hnsw_index, xq[0], k=1, ef=128) 
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))

# %%
print(result)
print(gt[0,0])

# %%
print(len(search_path_local_ID), search_path_local_ID)

# %%
print(search_path_vec_ID)

# %%
# sorted_search_path_vec_ID = sorted(list(search_path_vec_ID)) 
# sorted_search_path_local_ID = sorted(list(search_path_local_ID))

# for i in range(len(sorted_search_path_local_ID)):
#     if sorted_search_path_local_ID[i] != sorted_search_path_vec_ID[i]:
#         print("i = {}\tsorted_search_path_local_ID = {}\tsorted_search_path_vec_ID = {}".format(
#             i, sorted_search_path_local_ID[i], sorted_search_path_vec_ID[i]))

# %%
remote_index_path='../indexes_subgraph/SIFT1M_index_subgraph_1.bin'.format(dbname)
remote_hnswlib_index = hnswlib.Index(space='l2', dim=dim)  # the space can be changed - keeps the data, alters the distance function.
print("\nLoading index from {}\n".format(index_path))
remote_hnswlib_index.load_index(remote_index_path)

# %%
remote_hnswlib_indexes = [remote_hnswlib_index]
remote_server_IDs = [1]

t0 = time.time()
HNSW_index.insertRemote(hnsw_index, remote_hnswlib_indexes, remote_server_IDs, ef=128)
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))

# %%
# Search local + remote cache
results, local_results, remote_results, search_remote, remote_server_ID = \
    HNSW_index.searchKnnPlusRemoteCache(hnsw_index, xq[0], k=1, ef=128, all_vectors=xb, debug=True)

# %%
print(search_remote)

# %%
print(results)
print(local_results)
print(remote_results)
print(gt[0][0])

# %%
result_list = []
search_remote_list = []
query_num = 10000

for i in range(query_num):
    results, local_results, remote_results, search_remote, remote_server_ID = HNSW_index.searchKnnPlusRemoteCache(hnsw_index, xq[i], k=1, ef=128, all_vectors=xb, debug=False)
    result_list.append(results[-1])
    search_remote_list.append(search_remote)

# %%
## Get recall for consider up to 1 remote hop
## Wenqi comment: even just 1 hop can reach 97% recall!!!
# First 100 queries -> 0.97 recall
# First 1000 queries -> 0.990 recall
# First 10000 queries -> 0.9949 recall (visit remote graph = 0.9978)

count = 0
for i in range(query_num):
    ID = result_list[i][2]
    if ID == gt[i][0]: count += 1
print(count/query_num, count)

# %%
# Count how many searches travel to remote node

search_remote_count = 0
for i in range(query_num):
    if search_remote_list[i]: search_remote_count += 1
print(search_remote_count/query_num, search_remote_count)

# %%
# Search local + remote when needed
remote_hnswlib_indexes = [remote_hnswlib_index]
remote_server_IDs = [1]

HNSW_index.searchKnnPlusRemote(
    hnsw_index, xq[0], k=10, ef=128, all_vectors=xb, 
    remote_hnswlib_indexes=remote_hnswlib_indexes, remote_server_IDs=remote_server_IDs, debug=False)

# %%
result_list = []
search_remote_list = []
query_num = 100

for i in range(query_num):
    results, search_remote = HNSW_index.searchKnnPlusRemote(
        hnsw_index, xq[i], k=1, ef=128, all_vectors=xb, 
        remote_hnswlib_indexes=remote_hnswlib_indexes, remote_server_IDs=remote_server_IDs, debug=False)
    result_list.append(results[-1])
    search_remote_list.append(search_remote)

# %%
## Get recall for local + remote
## for first 100 queries; 1 hop can reach 97%; lazy evaluation search all = 98% recall (maybe good partitioning can solve it?)
# First 1000 queries -> 0.993 recall
# First 10000 queries -> 0.9978 -> Very high, should be high enough, so lazy evaluation should work well!

count = 0
for i in range(query_num):
    ID = result_list[i][2]
    if ID == gt[i][0]: count += 1
print(count/query_num, count)

# %%
# Count how many searches travel to remote node
# for 10000 queris, 50.19% of search travels to the other server

search_remote_count = 0
for i in range(query_num):
    if search_remote_list[i]: search_remote_count += 1
print(search_remote_count/query_num, search_remote_count)

# %% [markdown]
# ## Example 2: 4 sub-graphs

# %%
from pathlib import Path
index_path='../indexes_subgraph_kmeans/SIFT1M_4_subgraphs/subgraph_0.bin'#.format(dbname)
index = Path(index_path).read_bytes()
print('size: ', len(index))
# Out:
# size:  237123624

# %%
hnsw_index = HNSW_index(local_server_ID=0, dim=128)
hnsw_index.load_meta_info(index)
# Out:
# offsetLevel0_ 0
# max_elements_ 358987
# cur_element_count 358987
# size_data_per_element_ 652
# label_offset_ 644
# offsetData_ 132
# maxlevel_ 4
# enterpoint_node_ 81740
# maxM_ 16
# maxM0_ 32
# M_ 16
# mult_ 0.36067376022224085
# ef_construction_ 128

# %%
t0 = time.time()
HNSW_index.load_ground_layer(hnsw_index, index)
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))
# Out:
# time consumption: 1.76 sec

# %%
t0 = time.time()
HNSW_index.load_upper_layers(hnsw_index, index)
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))
# Out:
# time consumption: 0.58 sec

# %%
# Search local
t0 = time.time()
result, search_path_local_ID, search_path_vec_ID = HNSW_index.searchKnn(hnsw_index, xq[0], k=1, ef=128) 
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))
# Out:
# time consumption: 0.05 sec

# %%
print(result)
print(gt[0,0])
# Out:
# [[61125.0, 0, 504814]]
# 504814

# %%
remote_server_IDs = [1,2,3]
remote_index_paths=['../indexes_subgraph_kmeans/SIFT1M_4_subgraphs/subgraph_{}.bin'.format(i) for i in remote_server_IDs]
remote_hnswlib_indexes = [hnswlib.Index(space='l2', dim=dim) for i in remote_server_IDs]
for i, id in enumerate(remote_index_paths):
    print("\nLoading index from {}\n".format(remote_index_paths[i]))
    remote_hnswlib_indexes[i].load_index(remote_index_paths[i])
# Out:
# Loading index from ../indexes_subgraph_kmeans/SIFT1M_4_subgraphs/subgraph_1.bin
#
#
# Loading index from ../indexes_subgraph_kmeans/SIFT1M_4_subgraphs/subgraph_2.bin
#
#
# Loading index from ../indexes_subgraph_kmeans/SIFT1M_4_subgraphs/subgraph_3.bin

# %%
t0 = time.time()
HNSW_index.insertRemote(hnsw_index, remote_hnswlib_indexes, remote_server_IDs, ef=128)
t1 = time.time()
print("time consumption: {:.2f} sec".format(t1 - t0))
# Out:
# time consumption: 61.47 sec

# %%
# Search local + remote cache
results, local_results, remote_results, search_remote, remote_server_ID = \
    HNSW_index.searchKnnPlusRemoteCache(hnsw_index, xq[0], k=1, ef=128, all_vectors=xb, debug=True)
# Out:
# level:  4
# current object:  81740 , current distance:  165691.0
# size of neighbors:  1
# cand:  174389 , dist:  128028.0
# changed
# one node finish
#
# current object:  174389 , current distance:  128028.0
# size of neighbors:  1
# cand:  81740 , dist:  165691.0
# one node finish
#
#
# level:  3
# current object:  174389 , current distance:  128028.0
# size of neighbors:  13
# cand:  35129 , dist:  257286.0
# cand:  49352 , dist:  146393.0
# cand:  81740 , dist:  165691.0
# cand:  38272 , dist:  183160.0
# cand:  168648 , dist:  192195.0
# cand:  116957 , dist:  208710.0
# cand:  28596 , dist:  181070.0
# cand:  102760 , dist:  143478.0
# cand:  210280 , dist:  129749.0
# cand:  214868 , dist:  101316.0
# changed
# cand:  259501 , dist:  143103.0
# cand:  276429 , dist:  180164.0
# cand:  331205 , dist:  192026.0
# one node finish
#
# current object:  214868 , current distance:  101316.0
# size of neighbors:  6
# cand:  67199 , dist:  175542.0
# cand:  95630 , dist:  182769.0
# cand:  116957 , dist:  208710.0
# cand:  174389 , dist:  128028.0
# cand:  210280 , dist:  129749.0
# cand:  259501 , dist:  143103.0
# one node finish
#
#
# level:  2
# current object:  214868 , current distance:  101316.0
# size of neighbors:  11
# cand:  211077 , dist:  129692.0
# cand:  105361 , dist:  161921.0
# cand:  306673 , dist:  171634.0
# cand:  66947 , dist:  158713.0
# cand:  229592 , dist:  134675.0
# cand:  204822 , dist:  145918.0
# cand:  207697 , dist:  158532.0
# cand:  260391 , dist:  157629.0
# cand:  280886 , dist:  167073.0
# cand:  259501 , dist:  143103.0
# cand:  75206 , dist:  129359.0
# one node finish
#
#
# level:  1
# current object:  214868 , current distance:  101316.0
# size of neighbors:  15
# cand:  229592 , dist:  134675.0
# cand:  217966 , dist:  125427.0
# cand:  200896 , dist:  146214.0
# cand:  250013 , dist:  168962.0
# cand:  210181 , dist:  171866.0
# cand:  95611 , dist:  146697.0
# cand:  169655 , dist:  165817.0
# cand:  337069 , dist:  173085.0
# cand:  88682 , dist:  183112.0
# cand:  280886 , dist:  167073.0
# cand:  119031 , dist:  130265.0
# cand:  259501 , dist:  143103.0
# cand:  316060 , dist:  148521.0
# cand:  106403 , dist:  105703.0
# cand:  75206 , dist:  129359.0
# one node finish
#
#
# level: 0
# current object:  214868
# size of neighbors:  21
# current object:  81295 , current distance:  156984.0 , lowerBound:  101316.0
# added
# current object:  172238 , current distance:  164776.0 , lowerBound:  156984.0
# added
# current object:  78640 , current distance:  136050.0 , lowerBound:  164776.0
# added
# current object:  131842 , current distance:  154443.0 , lowerBound:  164776.0
# added
# current object:  11020 , current distance:  157937.0 , lowerBound:  164776.0
# added
# current object:  106403 , current distance:  105703.0 , lowerBound:  164776.0
# added
# current object:  163042 , current distance:  125993.0 , lowerBound:  164776.0
# added
# current object:  119005 , current distance:  117626.0 , lowerBound:  164776.0
# added
# current object:  60103 , current distance:  150585.0 , lowerBound:  164776.0
# added
# current object:  112914 , current distance:  165412.0 , lowerBound:  164776.0
# added
# current object:  10608 , current distance:  150070.0 , lowerBound:  165412.0
# added
# current object:  150282 , current distance:  140027.0 , lowerBound:  165412.0
# added
# current object:  242264 , current distance:  124994.0 , lowerBound:  165412.0
# added
# current object:  248467 , current distance:  133156.0 , lowerBound:  165412.0
# added
# current object:  285009 , current distance:  133549.0 , lowerBound:  165412.0
# added
# current object:  293731 , current distance:  144241.0 , lowerBound:  165412.0
# added
# current object:  319743 , current distance:  127965.0 , lowerBound:  165412.0
# added
# current object:  324634 , current distance:  141598.0 , lowerBound:  165412.0
# added
# current object:  337323 , current distance:  128152.0 , lowerBound:  165412.0
# added
# current object:  353154 , current distance:  133780.0 , lowerBound:  165412.0
# added
# current object:  353657 , current distance:  145804.0 , lowerBound:  165412.0
# added
# one node finishes
#
# current object:  106403
# size of neighbors:  13
# current object:  35155 , current distance:  119923.0 , lowerBound:  165412.0
# added
# current object:  61446 , current distance:  174063.0 , lowerBound:  165412.0
# added
# current object:  105550 , current distance:  146091.0 , lowerBound:  174063.0
# added
# current object:  105019 , current distance:  126013.0 , lowerBound:  174063.0
# added
# current object:  76936 , current distance:  141795.0 , lowerBound:  174063.0
# added
# current object:  106050 , current distance:  130554.0 , lowerBound:  174063.0
# added
# current object:  77223 , current distance:  158288.0 , lowerBound:  174063.0
# added
# current object:  4853 , current distance:  120717.0 , lowerBound:  174063.0
# added
# current object:  27475 , current distance:  132755.0 , lowerBound:  174063.0
# added
# current object:  118805 , current distance:  116916.0 , lowerBound:  174063.0
# added
# current object:  119559 , current distance:  150326.0 , lowerBound:  174063.0
# added
# current object:  214868 , visited already
# current object:  298138 , current distance:  171222.0 , lowerBound:  174063.0
# added
# one node finishes
#
# current object:  118805
# size of neighbors:  24
# current object:  143822 , current distance:  147350.0 , lowerBound:  174063.0
# added
# current object:  16372 , current distance:  170852.0 , lowerBound:  174063.0
# added
# current object:  106403 , visited already
# current object:  106339 , current distance:  130278.0 , lowerBound:  174063.0
# added
# current object:  56645 , current distance:  174386.0 , lowerBound:  174063.0
# added
# current object:  118760 , current distance:  122673.0 , lowerBound:  174386.0
# added
# current object:  76936 , visited already
# current object:  118787 , current distance:  115248.0 , lowerBound:  174386.0
# added
# current object:  119005 , visited already
# current object:  118795 , current distance:  120192.0 , lowerBound:  174386.0
# added
# current object:  119032 , current distance:  129370.0 , lowerBound:  174386.0
# added
# current object:  152460 , current distance:  152606.0 , lowerBound:  174386.0
# added
# current object:  154556 , current distance:  164275.0 , lowerBound:  174386.0
# added
# current object:  170521 , current distance:  150481.0 , lowerBound:  174386.0
# added
# current object:  205149 , current distance:  130671.0 , lowerBound:  174386.0
# added
# current object:  207681 , current distance:  146965.0 , lowerBound:  174386.0
# added
# current object:  210145 , current distance:  144699.0 , lowerBound:  174386.0
# added
# current object:  211444 , current distance:  185381.0 , lowerBound:  174386.0
# added
# current object:  217163 , current distance:  145632.0 , lowerBound:  185381.0
# added
# current object:  218810 , current distance:  170665.0 , lowerBound:  185381.0
# added
# current object:  261257 , current distance:  193654.0 , lowerBound:  185381.0
# added
# current object:  284784 , current distance:  124919.0 , lowerBound:  193654.0
# added
# current object:  320618 , current distance:  157644.0 , lowerBound:  193654.0
# added
# current object:  341119 , current distance:  189700.0 , lowerBound:  193654.0
# added
# one node finishes
#
# current object:  118787
# size of neighbors:  32
# current object:  161098 , current distance:  155169.0 , lowerBound:  193654.0
# added
# current object:  121707 , current distance:  117534.0 , lowerBound:  193654.0
# added
# current object:  194492 , current distance:  141909.0 , lowerBound:  193654.0
# added
# current object:  181449 , current distance:  166891.0 , lowerBound:  193654.0
# added
# current object:  125918 , current distance:  180555.0 , lowerBound:  193654.0
# added
# current object:  333478 , current distance:  150336.0 , lowerBound:  193654.0
# added
# current object:  153532 , current distance:  147384.0 , lowerBound:  193654.0
# added
# current object:  210156 , current distance:  137962.0 , lowerBound:  193654.0
# added
# current object:  154555 , current distance:  151555.0 , lowerBound:  193654.0
# added
# current object:  219234 , current distance:  145150.0 , lowerBound:  193654.0
# added
# current object:  243084 , current distance:  156411.0 , lowerBound:  193654.0
# added
# current object:  140588 , current distance:  141595.0 , lowerBound:  193654.0
# added
# current object:  194456 , current distance:  115951.0 , lowerBound:  193654.0
# added
# current object:  28150 , current distance:  137955.0 , lowerBound:  193654.0
# added
# current object:  119064 , current distance:  153182.0 , lowerBound:  193654.0
# added
# current object:  182462 , current distance:  175371.0 , lowerBound:  193654.0
# added
# current object:  106130 , current distance:  181634.0 , lowerBound:  193654.0
# added
# current object:  126911 , current distance:  129990.0 , lowerBound:  193654.0
# added
# current object:  216895 , current distance:  130269.0 , lowerBound:  193654.0
# added
# current object:  98745 , current distance:  156948.0 , lowerBound:  193654.0
# added
# current object:  283693 , current distance:  138720.0 , lowerBound:  193654.0
# added
# current object:  38454 , current distance:  118678.0 , lowerBound:  193654.0
# added
# current object:  28561 , current distance:  118357.0 , lowerBound:  193654.0
# added
# current object:  181246 , current distance:  128033.0 , lowerBound:  193654.0
# added
# current object:  182189 , current distance:  110770.0 , lowerBound:  193654.0
# added
# current object:  118751 , current distance:  137415.0 , lowerBound:  193654.0
# added
# current object:  119057 , current distance:  130956.0 , lowerBound:  193654.0
# added
# current object:  119043 , current distance:  133736.0 , lowerBound:  193654.0
# added
# current object:  118805 , visited already
# current object:  196386 , current distance:  97971.0 , lowerBound:  193654.0
# added
# current object:  224880 , current distance:  117537.0 , lowerBound:  193654.0
# added
# current object:  118783 , current distance:  140513.0 , lowerBound:  193654.0
# added
# one node finishes
#
# current object:  196386
# size of neighbors:  32
# current object:  41536 , current distance:  113680.0 , lowerBound:  193654.0
# added
# current object:  188776 , current distance:  130604.0 , lowerBound:  193654.0
# added
# current object:  24991 , current distance:  151478.0 , lowerBound:  193654.0
# added
# current object:  93549 , current distance:  129641.0 , lowerBound:  193654.0
# added
# current object:  9504 , current distance:  136305.0 , lowerBound:  193654.0
# added
# current object:  182197 , current distance:  132576.0 , lowerBound:  193654.0
# added
# current object:  182209 , current distance:  123636.0 , lowerBound:  193654.0
# added
# current object:  118758 , current distance:  139880.0 , lowerBound:  193654.0
# added
# current object:  80604 , current distance:  118438.0 , lowerBound:  193654.0
# added
# current object:  182373 , current distance:  127338.0 , lowerBound:  193654.0
# added
# current object:  182237 , current distance:  85222.0 , lowerBound:  193654.0
# added
# current object:  182372 , current distance:  124225.0 , lowerBound:  193654.0
# added
# current object:  119046 , current distance:  124064.0 , lowerBound:  193654.0
# added
# current object:  118800 , current distance:  126184.0 , lowerBound:  193654.0
# added
# current object:  182263 , current distance:  97321.0 , lowerBound:  193654.0
# added
# current object:  118787 , visited already
# current object:  196520 , current distance:  129379.0 , lowerBound:  193654.0
# added
# current object:  205880 , current distance:  110834.0 , lowerBound:  193654.0
# added
# current object:  215240 , current distance:  99898.0 , lowerBound:  193654.0
# added
# current object:  216559 , current distance:  128597.0 , lowerBound:  193654.0
# added
# current object:  216927 , current distance:  155816.0 , lowerBound:  193654.0
# added
# current object:  219112 , current distance:  191704.0 , lowerBound:  193654.0
# added
# current object:  226444 , current distance:  87902.0 , lowerBound:  193654.0
# added
# current object:  264806 , current distance:  176964.0 , lowerBound:  193654.0
# added
# current object:  273612 , current distance:  106650.0 , lowerBound:  193654.0
# added
# current object:  285147 , current distance:  135677.0 , lowerBound:  193654.0
# added
# current object:  285173 , current distance:  124508.0 , lowerBound:  193654.0
# added
# current object:  291340 , current distance:  164687.0 , lowerBound:  193654.0
# added
# current object:  303487 , current distance:  153115.0 , lowerBound:  193654.0
# added
# current object:  331306 , current distance:  164384.0 , lowerBound:  193654.0
# added
# current object:  333240 , current distance:  92973.0 , lowerBound:  193654.0
# added
# current object:  356295 , current distance:  161824.0 , lowerBound:  193654.0
# added
# one node finishes
#
# current object:  182237
# size of neighbors:  29
# current object:  304972 , current distance:  156117.0 , lowerBound:  193654.0
# added
# current object:  266130 , current distance:  122502.0 , lowerBound:  193654.0
# added
# current object:  333340 , current distance:  126776.0 , lowerBound:  193654.0
# added
# current object:  233819 , current distance:  98108.0 , lowerBound:  193654.0
# added
# current object:  296803 , current distance:  127210.0 , lowerBound:  193654.0
# added
# current object:  238784 , current distance:  129046.0 , lowerBound:  193654.0
# added
# current object:  195810 , current distance:  132478.0 , lowerBound:  193654.0
# added
# current object:  249276 , current distance:  140632.0 , lowerBound:  193654.0
# added
# current object:  333272 , current distance:  102982.0 , lowerBound:  193654.0
# added
# current object:  303381 , current distance:  104316.0 , lowerBound:  193654.0
# added
# current object:  16248 , current distance:  141868.0 , lowerBound:  193654.0
# added
# current object:  103674 , current distance:  102927.0 , lowerBound:  193654.0
# added
# current object:  155079 , current distance:  126910.0 , lowerBound:  191704.0
# added
# current object:  20924 , current distance:  123362.0 , lowerBound:  189700.0
# added
# current object:  182206 , current distance:  99684.0 , lowerBound:  185381.0
# added
# current object:  188885 , current distance:  139025.0 , lowerBound:  181634.0
# added
# current object:  210297 , current distance:  93694.0 , lowerBound:  180555.0
# added
# current object:  205037 , current distance:  124494.0 , lowerBound:  176964.0
# added
# current object:  182189 , visited already
# current object:  273589 , current distance:  128119.0 , lowerBound:  175371.0
# added
# current object:  288618 , current distance:  142650.0 , lowerBound:  174386.0
# added
# current object:  182357 , current distance:  61125.0 , lowerBound:  174063.0
# added
# current object:  196386 , visited already
# current object:  289150 , current distance:  124709.0 , lowerBound:  171222.0
# added
# current object:  2913 , current distance:  101836.0 , lowerBound:  170852.0
# added
# current object:  182352 , current distance:  132527.0 , lowerBound:  170665.0
# added
# current object:  338187 , current distance:  115145.0 , lowerBound:  166891.0
# added
# current object:  182247 , current distance:  111890.0 , lowerBound:  165412.0
# added
# current object:  341675 , current distance:  130585.0 , lowerBound:  164776.0
# added
# one node finishes
#
# current object:  182357
# size of neighbors:  29
# current object:  74662 , current distance:  108755.0 , lowerBound:  164687.0
# added
# current object:  82059 , current distance:  92378.0 , lowerBound:  164384.0
# added
# current object:  106480 , current distance:  120425.0 , lowerBound:  164275.0
# added
# current object:  73851 , current distance:  77515.0 , lowerBound:  161824.0
# added
# current object:  106057 , current distance:  120762.0 , lowerBound:  158288.0
# added
# current object:  106425 , current distance:  107625.0 , lowerBound:  157937.0
# added
# current object:  98406 , current distance:  114018.0 , lowerBound:  157644.0
# added
# current object:  63301 , current distance:  130461.0 , lowerBound:  156984.0
# added
# current object:  119036 , current distance:  129843.0 , lowerBound:  156948.0
# added
# current object:  145528 , current distance:  116796.0 , lowerBound:  156411.0
# added
# current object:  106402 , current distance:  106156.0 , lowerBound:  156117.0
# added
# current object:  78819 , current distance:  91490.0 , lowerBound:  155816.0
# added
# current object:  182234 , current distance:  108127.0 , lowerBound:  155169.0
# added
# current object:  182237 , visited already
# current object:  118939 , current distance:  114747.0 , lowerBound:  154443.0
# added
# current object:  194534 , current distance:  90665.0 , lowerBound:  153182.0
# added
# current object:  196273 , current distance:  99304.0 , lowerBound:  153115.0
# added
# current object:  210000 , current distance:  128451.0 , lowerBound:  152606.0
# added
# current object:  210816 , current distance:  108092.0 , lowerBound:  151555.0
# added
# current object:  210771 , current distance:  107391.0 , lowerBound:  151478.0
# added
# current object:  210838 , current distance:  110262.0 , lowerBound:  150585.0
# added
# current object:  211072 , current distance:  92904.0 , lowerBound:  150481.0
# added
# current object:  213378 , current distance:  126106.0 , lowerBound:  150336.0
# added
# current object:  267859 , current distance:  125848.0 , lowerBound:  150326.0
# added
# current object:  279792 , current distance:  107503.0 , lowerBound:  150070.0
# added
# current object:  317811 , current distance:  83564.0 , lowerBound:  147384.0
# added
# current object:  322896 , current distance:  73660.0 , lowerBound:  147350.0
# added
# current object:  333267 , current distance:  99567.0 , lowerBound:  146965.0
# added
# current object:  342979 , current distance:  105362.0 , lowerBound:  146091.0
# added
# one node finishes
#
# current object:  322896
# size of neighbors:  16
# current object:  153843 , current distance:  125987.0 , lowerBound:  145804.0
# added
# current object:  246172 , current distance:  115499.0 , lowerBound:  145632.0
# added
# current object:  276223 , current distance:  116439.0 , lowerBound:  145150.0
# added
# current object:  233819 , visited already
# current object:  288343 , current distance:  126861.0 , lowerBound:  144699.0
# added
# current object:  86213 , current distance:  104688.0 , lowerBound:  144241.0
# added
# current object:  218505 , current distance:  125227.0 , lowerBound:  142650.0
# added
# current object:  102342 , current distance:  121886.0 , lowerBound:  141909.0
# added
# current object:  153327 , current distance:  116315.0 , lowerBound:  141868.0
# added
# current object:  6198 , current distance:  143473.0 , lowerBound:  141795.0
# current object:  179275 , current distance:  123640.0 , lowerBound:  141795.0
# added
# current object:  134592 , current distance:  108222.0 , lowerBound:  141598.0
# added
# current object:  120119 , current distance:  132935.0 , lowerBound:  141595.0
# added
# current object:  319947 , current distance:  154858.0 , lowerBound:  140632.0
# current object:  317811 , visited already
# current object:  182357 , visited already
# one node finishes
#
# current object:  73851
# size of neighbors:  32
# current object:  153917 , current distance:  130962.0 , lowerBound:  140632.0
# added
# current object:  87594 , current distance:  150182.0 , lowerBound:  140513.0
# current object:  93113 , current distance:  158419.0 , lowerBound:  140513.0
# current object:  288350 , current distance:  141993.0 , lowerBound:  140513.0
# current object:  224765 , current distance:  166284.0 , lowerBound:  140513.0
# current object:  33932 , current distance:  128720.0 , lowerBound:  140513.0
# added
# current object:  39705 , current distance:  138282.0 , lowerBound:  140027.0
# added
# current object:  2944 , current distance:  121345.0 , lowerBound:  139880.0
# added
# current object:  28379 , current distance:  118425.0 , lowerBound:  139025.0
# added
# current object:  181736 , current distance:  138935.0 , lowerBound:  138720.0
# current object:  272441 , current distance:  170990.0 , lowerBound:  138720.0
# current object:  32753 , current distance:  103471.0 , lowerBound:  138720.0
# added
# current object:  113490 , current distance:  137893.0 , lowerBound:  138282.0
# added
# current object:  44486 , current distance:  126099.0 , lowerBound:  137962.0
# added
# current object:  174120 , current distance:  155814.0 , lowerBound:  137955.0
# current object:  120145 , current distance:  142122.0 , lowerBound:  137955.0
# current object:  66630 , current distance:  155063.0 , lowerBound:  137955.0
# current object:  7745 , current distance:  111117.0 , lowerBound:  137955.0
# added
# current object:  167108 , current distance:  146813.0 , lowerBound:  137893.0
# current object:  196354 , current distance:  109646.0 , lowerBound:  137893.0
# added
# current object:  27346 , current distance:  114126.0 , lowerBound:  137415.0
# added
# current object:  295271 , current distance:  140287.0 , lowerBound:  136305.0
# current object:  96872 , current distance:  129198.0 , lowerBound:  136305.0
# added
# current object:  154703 , current distance:  134594.0 , lowerBound:  136050.0
# added
# current object:  21666 , current distance:  95550.0 , lowerBound:  135677.0
# added
# current object:  182805 , current distance:  126866.0 , lowerBound:  134594.0
# added
# current object:  329411 , current distance:  153581.0 , lowerBound:  133780.0
# current object:  113234 , current distance:  136944.0 , lowerBound:  133780.0
# current object:  199978 , current distance:  138315.0 , lowerBound:  133780.0
# current object:  119639 , current distance:  153818.0 , lowerBound:  133780.0
# current object:  182357 , visited already
# current object:  304343 , current distance:  100711.0 , lowerBound:  133780.0
# added
# one node finishes
#
# current object:  317811
# size of neighbors:  20
# current object:  233039 , current distance:  147466.0 , lowerBound:  133736.0
# current object:  257610 , current distance:  122507.0 , lowerBound:  133736.0
# added
# current object:  182357 , visited already
# current object:  304214 , current distance:  142386.0 , lowerBound:  133549.0
# current object:  132917 , current distance:  122030.0 , lowerBound:  133549.0
# added
# current object:  135015 , current distance:  141881.0 , lowerBound:  133156.0
# current object:  182260 , current distance:  146101.0 , lowerBound:  133156.0
# current object:  16094 , current distance:  124288.0 , lowerBound:  133156.0
# added
# current object:  284538 , current distance:  136058.0 , lowerBound:  132935.0
# current object:  35379 , current distance:  136477.0 , lowerBound:  132935.0
# current object:  87613 , current distance:  155374.0 , lowerBound:  132935.0
# current object:  203260 , current distance:  120279.0 , lowerBound:  132935.0
# added
# current object:  82059 , visited already
# current object:  137874 , current distance:  123590.0 , lowerBound:  132755.0
# added
# current object:  220352 , current distance:  125864.0 , lowerBound:  132576.0
# added
# current object:  115606 , current distance:  141072.0 , lowerBound:  132527.0
# current object:  322896 , visited already
# current object:  324987 , current distance:  149094.0 , lowerBound:  132527.0
# current object:  341950 , current distance:  121868.0 , lowerBound:  132527.0
# added
# current object:  356443 , current distance:  118664.0 , lowerBound:  132478.0
# added
# one node finishes
#
# current object:  226444
# size of neighbors:  20
# current object:  165742 , current distance:  130009.0 , lowerBound:  130962.0
# added
# current object:  58050 , current distance:  150726.0 , lowerBound:  130956.0
# current object:  203150 , current distance:  146466.0 , lowerBound:  130956.0
# current object:  214656 , current distance:  106301.0 , lowerBound:  130956.0
# added
# current object:  21040 , current distance:  136938.0 , lowerBound:  130671.0
# current object:  61526 , current distance:  117830.0 , lowerBound:  130671.0
# added
# current object:  38126 , current distance:  140623.0 , lowerBound:  130604.0
# current object:  154772 , current distance:  104911.0 , lowerBound:  130604.0
# added
# current object:  182247 , visited already
# current object:  190928 , current distance:  106635.0 , lowerBound:  130585.0
# added
# current object:  74662 , visited already
# current object:  47396 , current distance:  125530.0 , lowerBound:  130554.0
# added
# current object:  182343 , current distance:  111135.0 , lowerBound:  130461.0
# added
# current object:  196386 , visited already
# current object:  244020 , current distance:  139539.0 , lowerBound:  130278.0
# current object:  260608 , current distance:  133655.0 , lowerBound:  130278.0
# current object:  288621 , current distance:  125730.0 , lowerBound:  130278.0
# added
# current object:  333263 , current distance:  100340.0 , lowerBound:  130269.0
# added
# current object:  333452 , current distance:  137626.0 , lowerBound:  130009.0
# current object:  338658 , current distance:  147146.0 , lowerBound:  130009.0
# one node finishes
#
# current object:  194534
# size of neighbors:  22
# current object:  110851 , current distance:  163920.0 , lowerBound:  130009.0
# current object:  85025 , current distance:  161465.0 , lowerBound:  130009.0
# current object:  18715 , current distance:  146555.0 , lowerBound:  130009.0
# current object:  166212 , current distance:  137145.0 , lowerBound:  130009.0
# current object:  90181 , current distance:  186730.0 , lowerBound:  130009.0
# current object:  124732 , current distance:  167657.0 , lowerBound:  130009.0
# current object:  157350 , current distance:  140730.0 , lowerBound:  130009.0
# current object:  106377 , current distance:  121841.0 , lowerBound:  130009.0
# added
# current object:  165793 , current distance:  140577.0 , lowerBound:  129990.0
# current object:  106485 , current distance:  125977.0 , lowerBound:  129990.0
# added
# current object:  86213 , visited already
# current object:  73572 , current distance:  121197.0 , lowerBound:  129843.0
# added
# current object:  105538 , current distance:  101980.0 , lowerBound:  129641.0
# added
# current object:  123769 , current distance:  131100.0 , lowerBound:  129379.0
# current object:  182357 , visited already
# current object:  175863 , current distance:  107505.0 , lowerBound:  129379.0
# added
# current object:  196354 , visited already
# current object:  247359 , current distance:  150364.0 , lowerBound:  129370.0
# current object:  299758 , current distance:  130552.0 , lowerBound:  129370.0
# current object:  300157 , current distance:  170733.0 , lowerBound:  129370.0
# current object:  341186 , current distance:  124233.0 , lowerBound:  129370.0
# added
# current object:  341823 , current distance:  152366.0 , lowerBound:  129198.0
# one node finishes
#
# current object:  78819
# size of neighbors:  29
# current object:  118278 , current distance:  112551.0 , lowerBound:  129198.0
# added
# current object:  106358 , current distance:  100576.0 , lowerBound:  129046.0
# added
# current object:  182357 , visited already
# current object:  118004 , current distance:  100057.0 , lowerBound:  128720.0
# added
# current object:  289106 , current distance:  101464.0 , lowerBound:  128597.0
# added
# current object:  13115 , current distance:  147110.0 , lowerBound:  128451.0
# current object:  65252 , current distance:  113867.0 , lowerBound:  128451.0
# added
# current object:  284869 , current distance:  130943.0 , lowerBound:  128152.0
# current object:  175867 , current distance:  106757.0 , lowerBound:  128152.0
# added
# current object:  164188 , current distance:  136666.0 , lowerBound:  128119.0
# current object:  65859 , current distance:  122735.0 , lowerBound:  128119.0
# added
# current object:  41899 , current distance:  129016.0 , lowerBound:  128033.0
# current object:  37926 , current distance:  128737.0 , lowerBound:  128033.0
# current object:  110551 , current distance:  128412.0 , lowerBound:  128033.0
# current object:  303884 , current distance:  158944.0 , lowerBound:  128033.0
# current object:  200401 , current distance:  145287.0 , lowerBound:  128033.0
# current object:  76936 , visited already
# current object:  182278 , current distance:  105685.0 , lowerBound:  128033.0
# added
# current object:  140958 , current distance:  135057.0 , lowerBound:  127965.0
# current object:  27628 , current distance:  142113.0 , lowerBound:  127965.0
# current object:  207481 , current distance:  137903.0 , lowerBound:  127965.0
# current object:  246143 , current distance:  138852.0 , lowerBound:  127965.0
# current object:  99177 , current distance:  119358.0 , lowerBound:  127965.0
# added
# current object:  233856 , current distance:  123315.0 , lowerBound:  127338.0
# added
# current object:  338167 , current distance:  108959.0 , lowerBound:  127210.0
# added
# current object:  93883 , current distance:  121566.0 , lowerBound:  126910.0
# added
# current object:  106352 , current distance:  111302.0 , lowerBound:  126866.0
# added
# current object:  353058 , current distance:  122336.0 , lowerBound:  126861.0
# added
# current object:  358499 , current distance:  128803.0 , lowerBound:  126776.0
# one node finishes
#
# current object:  82059
# size of neighbors:  32
# current object:  169532 , current distance:  160898.0 , lowerBound:  126776.0
# current object:  134383 , current distance:  121840.0 , lowerBound:  126776.0
# added
# current object:  330771 , current distance:  146370.0 , lowerBound:  126184.0
# current object:  50087 , current distance:  172008.0 , lowerBound:  126184.0
# current object:  164258 , current distance:  92837.0 , lowerBound:  126184.0
# added
# current object:  123856 , current distance:  62943.0 , lowerBound:  126106.0
# added
# current object:  164674 , current distance:  111217.0 , lowerBound:  126099.0
# added
# current object:  63399 , current distance:  120133.0 , lowerBound:  126013.0
# added
# current object:  101249 , current distance:  107021.0 , lowerBound:  125993.0
# added
# current object:  341752 , current distance:  138239.0 , lowerBound:  125987.0
# current object:  207138 , current distance:  127746.0 , lowerBound:  125987.0
# current object:  238870 , current distance:  156381.0 , lowerBound:  125987.0
# current object:  202510 , current distance:  128877.0 , lowerBound:  125987.0
# current object:  352510 , current distance:  122907.0 , lowerBound:  125987.0
# added
# current object:  49622 , current distance:  125001.0 , lowerBound:  125977.0
# added
# current object:  238654 , current distance:  122322.0 , lowerBound:  125864.0
# added
# current object:  148365 , current distance:  118777.0 , lowerBound:  125848.0
# added
# current object:  63965 , current distance:  140691.0 , lowerBound:  125730.0
# current object:  313614 , current distance:  147437.0 , lowerBound:  125730.0
# current object:  167906 , current distance:  139265.0 , lowerBound:  125730.0
# current object:  262963 , current distance:  142822.0 , lowerBound:  125730.0
# current object:  231635 , current distance:  150000.0 , lowerBound:  125730.0
# current object:  3344 , current distance:  115729.0 , lowerBound:  125730.0
# added
# current object:  253048 , current distance:  139961.0 , lowerBound:  125530.0
# current object:  194447 , current distance:  132282.0 , lowerBound:  125530.0
# current object:  132097 , current distance:  108257.0 , lowerBound:  125530.0
# added
# current object:  77626 , current distance:  148755.0 , lowerBound:  125227.0
# current object:  128670 , current distance:  121827.0 , lowerBound:  125227.0
# added
# current object:  265591 , current distance:  139336.0 , lowerBound:  125001.0
# current object:  317811 , visited already
# current object:  27355 , current distance:  147482.0 , lowerBound:  125001.0
# current object:  336557 , current distance:  120498.0 , lowerBound:  125001.0
# added
# one node finishes
#
# current object:  123856
# size of neighbors:  24
# current object:  43468 , current distance:  115465.0 , lowerBound:  124994.0
# added
# current object:  120136 , current distance:  112905.0 , lowerBound:  124919.0
# added
# current object:  37771 , current distance:  124643.0 , lowerBound:  124709.0
# added
# current object:  121050 , current distance:  123582.0 , lowerBound:  124643.0
# added
# current object:  35083 , current distance:  104574.0 , lowerBound:  124508.0
# added
# current object:  69362 , current distance:  138720.0 , lowerBound:  124494.0
# current object:  104954 , current distance:  159293.0 , lowerBound:  124494.0
# current object:  40833 , current distance:  105833.0 , lowerBound:  124494.0
# added
# current object:  106425 , visited already
# current object:  111930 , current distance:  105948.0 , lowerBound:  124288.0
# added
# current object:  12072 , current distance:  117202.0 , lowerBound:  124233.0
# added
# current object:  82059 , visited already
# current object:  106311 , current distance:  93644.0 , lowerBound:  124225.0
# added
# current object:  85623 , current distance:  107371.0 , lowerBound:  124064.0
# added
# current object:  128139 , current distance:  139241.0 , lowerBound:  123640.0
# current object:  129324 , current distance:  135408.0 , lowerBound:  123640.0
# current object:  143890 , current distance:  103654.0 , lowerBound:  123640.0
# added
# current object:  146271 , current distance:  132412.0 , lowerBound:  123636.0
# current object:  155726 , current distance:  161302.0 , lowerBound:  123636.0
# current object:  210671 , current distance:  101291.0 , lowerBound:  123636.0
# added
# current object:  250985 , current distance:  146043.0 , lowerBound:  123590.0
# current object:  273938 , current distance:  149063.0 , lowerBound:  123590.0
# current object:  341248 , current distance:  152522.0 , lowerBound:  123590.0
# current object:  357042 , current distance:  129991.0 , lowerBound:  123590.0
# one node finishes
#
# current object:  164258
# size of neighbors:  31
# current object:  12176 , current distance:  151510.0 , lowerBound:  123590.0
# current object:  142503 , current distance:  177598.0 , lowerBound:  123590.0
# current object:  127507 , current distance:  142575.0 , lowerBound:  123590.0
# current object:  146271 , visited already
# current object:  82059 , visited already
# current object:  29750 , current distance:  142615.0 , lowerBound:  123590.0
# current object:  102490 , current distance:  122359.0 , lowerBound:  123590.0
# added
# current object:  31601 , current distance:  113832.0 , lowerBound:  123582.0
# added
# current object:  112309 , current distance:  140356.0 , lowerBound:  123362.0
# current object:  118067 , current distance:  121238.0 , lowerBound:  123362.0
# added
# current object:  102666 , current distance:  126709.0 , lowerBound:  123315.0
# current object:  118004 , visited already
# current object:  44999 , current distance:  132012.0 , lowerBound:  123315.0
# current object:  140560 , current distance:  120691.0 , lowerBound:  123315.0
# added
# current object:  69346 , current distance:  113104.0 , lowerBound:  122907.0
# added
# current object:  68840 , current distance:  112107.0 , lowerBound:  122735.0
# added
# current object:  166326 , current distance:  141286.0 , lowerBound:  122673.0
# current object:  169154 , current distance:  141468.0 , lowerBound:  122673.0
# current object:  185076 , current distance:  137060.0 , lowerBound:  122673.0
# current object:  187575 , current distance:  161603.0 , lowerBound:  122673.0
# current object:  217751 , current distance:  139292.0 , lowerBound:  122673.0
# current object:  229316 , current distance:  139994.0 , lowerBound:  122673.0
# current object:  229592 , current distance:  134675.0 , lowerBound:  122673.0
# current object:  236118 , current distance:  169649.0 , lowerBound:  122673.0
# current object:  238891 , current distance:  134957.0 , lowerBound:  122673.0
# current object:  239722 , current distance:  149602.0 , lowerBound:  122673.0
# current object:  283967 , current distance:  134073.0 , lowerBound:  122673.0
# current object:  302760 , current distance:  122212.0 , lowerBound:  122673.0
# added
# current object:  305547 , current distance:  163942.0 , lowerBound:  122507.0
# current object:  314257 , current distance:  134893.0 , lowerBound:  122507.0
# current object:  328960 , current distance:  113173.0 , lowerBound:  122507.0
# added
# one node finishes
#
# current object:  211072
# size of neighbors:  15
# current object:  57925 , current distance:  131576.0 , lowerBound:  122502.0
# current object:  106402 , visited already
# current object:  210199 , current distance:  108385.0 , lowerBound:  122502.0
# added
# current object:  27501 , current distance:  118264.0 , lowerBound:  122359.0
# added
# current object:  182357 , visited already
# current object:  118930 , current distance:  117545.0 , lowerBound:  122336.0
# added
# current object:  210458 , current distance:  94512.0 , lowerBound:  122322.0
# added
# current object:  210029 , current distance:  119075.0 , lowerBound:  122212.0
# added
# current object:  210962 , current distance:  117048.0 , lowerBound:  122030.0
# added
# current object:  210719 , current distance:  103518.0 , lowerBound:  121886.0
# added
# current object:  211080 , current distance:  107663.0 , lowerBound:  121868.0
# added
# current object:  211067 , current distance:  113531.0 , lowerBound:  121841.0
# added
# current object:  211112 , current distance:  110110.0 , lowerBound:  121840.0
# added
# current object:  211166 , current distance:  126473.0 , lowerBound:  121827.0
# current object:  211179 , current distance:  133689.0 , lowerBound:  121827.0
# one node finishes
#
# current object:  333240
# size of neighbors:  20
# current object:  86408 , current distance:  131870.0 , lowerBound:  121827.0
# current object:  134241 , current distance:  178793.0 , lowerBound:  121827.0
# current object:  235041 , current distance:  154500.0 , lowerBound:  121827.0
# current object:  306995 , current distance:  172695.0 , lowerBound:  121827.0
# current object:  35636 , current distance:  148909.0 , lowerBound:  121827.0
# current object:  63777 , current distance:  127708.0 , lowerBound:  121827.0
# current object:  209959 , current distance:  106609.0 , lowerBound:  121827.0
# added
# current object:  303768 , current distance:  137592.0 , lowerBound:  121566.0
# current object:  207868 , current distance:  126398.0 , lowerBound:  121566.0
# current object:  76953 , current distance:  113416.0 , lowerBound:  121566.0
# added
# current object:  140924 , current distance:  102660.0 , lowerBound:  121345.0
# added
# current object:  328981 , current distance:  106919.0 , lowerBound:  121238.0
# added
# current object:  47414 , current distance:  87341.0 , lowerBound:  121197.0
# added
# current object:  210705 , current distance:  120676.0 , lowerBound:  120762.0
# added
# current object:  180281 , current distance:  105415.0 , lowerBound:  120717.0
# added
# current object:  196386 , visited already
# current object:  333432 , current distance:  106852.0 , lowerBound:  120691.0
# added
# current object:  335249 , current distance:  113330.0 , lowerBound:  120676.0
# added
# current object:  339158 , current distance:  128461.0 , lowerBound:  120498.0
# current object:  339203 , current distance:  122807.0 , lowerBound:  120498.0
# one node finishes
#
# current object:  47414
# size of neighbors:  32
# current object:  106037 , current distance:  154158.0 , lowerBound:  120498.0
# current object:  47374 , current distance:  123973.0 , lowerBound:  120498.0
# current object:  221043 , current distance:  113222.0 , lowerBound:  120498.0
# added
# current object:  132808 , current distance:  143344.0 , lowerBound:  120425.0
# current object:  357978 , current distance:  128776.0 , lowerBound:  120425.0
# current object:  55736 , current distance:  138433.0 , lowerBound:  120425.0
# current object:  66023 , current distance:  137427.0 , lowerBound:  120425.0
# current object:  208123 , current distance:  113242.0 , lowerBound:  120425.0
# added
# current object:  277744 , current distance:  160432.0 , lowerBound:  120279.0
# current object:  24 , current distance:  130285.0 , lowerBound:  120279.0
# current object:  1690 , current distance:  174248.0 , lowerBound:  120279.0
# current object:  186998 , current distance:  111459.0 , lowerBound:  120279.0
# added
# current object:  31404 , current distance:  107619.0 , lowerBound:  120192.0
# added
# current object:  183819 , current distance:  110008.0 , lowerBound:  120133.0
# added
# current object:  123848 , current distance:  130597.0 , lowerBound:  119923.0
# current object:  249791 , current distance:  120632.0 , lowerBound:  119923.0
# current object:  255561 , current distance:  127316.0 , lowerBound:  119923.0
# current object:  243316 , current distance:  152669.0 , lowerBound:  119923.0
# current object:  65570 , current distance:  96188.0 , lowerBound:  119923.0
# added
# current object:  208194 , current distance:  118364.0 , lowerBound:  119358.0
# added
# current object:  357931 , current distance:  112562.0 , lowerBound:  119075.0
# added
# current object:  115099 , current distance:  143346.0 , lowerBound:  118777.0
# current object:  56104 , current distance:  150613.0 , lowerBound:  118777.0
# current object:  132900 , current distance:  101068.0 , lowerBound:  118777.0
# added
# current object:  91027 , current distance:  141483.0 , lowerBound:  118678.0
# current object:  2654 , current distance:  101308.0 , lowerBound:  118678.0
# added
# current object:  333240 , visited already
# current object:  47393 , current distance:  127433.0 , lowerBound:  118664.0
# current object:  233978 , current distance:  122612.0 , lowerBound:  118664.0
# current object:  200262 , current distance:  110853.0 , lowerBound:  118664.0
# added
# current object:  35399 , current distance:  131058.0 , lowerBound:  118438.0
# current object:  341159 , current distance:  103871.0 , lowerBound:  118438.0
# added
# one node finishes
#
# current object:  106311
# size of neighbors:  21
# current object:  142530 , current distance:  146659.0 , lowerBound:  118425.0
# current object:  202716 , current distance:  118180.0 , lowerBound:  118425.0
# added
# current object:  123856 , visited already
# current object:  224451 , current distance:  153125.0 , lowerBound:  118364.0
# current object:  7973 , current distance:  135628.0 , lowerBound:  118364.0
# current object:  118297 , current distance:  124416.0 , lowerBound:  118364.0
# current object:  129544 , current distance:  139519.0 , lowerBound:  118364.0
# current object:  90743 , current distance:  112627.0 , lowerBound:  118364.0
# added
# current object:  59146 , current distance:  135458.0 , lowerBound:  118357.0
# current object:  65218 , current distance:  155477.0 , lowerBound:  118357.0
# current object:  8743 , current distance:  142316.0 , lowerBound:  118357.0
# current object:  77518 , current distance:  169158.0 , lowerBound:  118357.0
# current object:  337145 , current distance:  121730.0 , lowerBound:  118357.0
# current object:  75781 , current distance:  140935.0 , lowerBound:  118357.0
# current object:  21206 , current distance:  110261.0 , lowerBound:  118357.0
# added
# current object:  210322 , current distance:  101889.0 , lowerBound:  118264.0
# added
# current object:  41033 , current distance:  118856.0 , lowerBound:  118180.0
# current object:  162801 , current distance:  126910.0 , lowerBound:  118180.0
# current object:  304295 , current distance:  140456.0 , lowerBound:  118180.0
# current object:  118283 , current distance:  98615.0 , lowerBound:  118180.0
# added
# current object:  158671 , current distance:  102796.0 , lowerBound:  117830.0
# added
# one node finishes
#
# current object:  210297
# size of neighbors:  28
# current object:  311286 , current distance:  176445.0 , lowerBound:  117626.0
# current object:  266267 , current distance:  143162.0 , lowerBound:  117626.0
# current object:  349238 , current distance:  154118.0 , lowerBound:  117626.0
# current object:  227724 , current distance:  114544.0 , lowerBound:  117626.0
# added
# current object:  333561 , current distance:  105661.0 , lowerBound:  117545.0
# added
# current object:  99114 , current distance:  101820.0 , lowerBound:  117537.0
# added
# current object:  109911 , current distance:  183952.0 , lowerBound:  117534.0
# current object:  51716 , current distance:  134032.0 , lowerBound:  117534.0
# current object:  134592 , visited already
# current object:  328914 , current distance:  114932.0 , lowerBound:  117534.0
# added
# current object:  224943 , current distance:  127181.0 , lowerBound:  117202.0
# current object:  241029 , current distance:  175632.0 , lowerBound:  117202.0
# current object:  168604 , current distance:  148979.0 , lowerBound:  117202.0
# current object:  111273 , current distance:  170759.0 , lowerBound:  117202.0
# current object:  91875 , current distance:  165290.0 , lowerBound:  117202.0
# current object:  294957 , current distance:  150071.0 , lowerBound:  117202.0
# current object:  192690 , current distance:  132970.0 , lowerBound:  117202.0
# current object:  65152 , current distance:  127884.0 , lowerBound:  117202.0
# current object:  338653 , current distance:  133381.0 , lowerBound:  117202.0
# current object:  162585 , current distance:  102886.0 , lowerBound:  117202.0
# added
# current object:  74847 , current distance:  93972.0 , lowerBound:  117048.0
# added
# current object:  351328 , current distance:  113700.0 , lowerBound:  116916.0
# added
# current object:  56913 , current distance:  121158.0 , lowerBound:  116796.0
# current object:  111549 , current distance:  115883.0 , lowerBound:  116796.0
# added
# current object:  182237 , visited already
# current object:  210295 , current distance:  124194.0 , lowerBound:  116439.0
# current object:  353190 , current distance:  143366.0 , lowerBound:  116439.0
# current object:  356533 , current distance:  143007.0 , lowerBound:  116439.0
# one node finishes
#
# current object:  74847
# size of neighbors:  32
# current object:  242273 , current distance:  136401.0 , lowerBound:  116439.0
# current object:  354014 , current distance:  139078.0 , lowerBound:  116439.0
# current object:  175931 , current distance:  96257.0 , lowerBound:  116439.0
# added
# current object:  234383 , current distance:  159774.0 , lowerBound:  116315.0
# current object:  207649 , current distance:  166995.0 , lowerBound:  116315.0
# current object:  335661 , current distance:  103090.0 , lowerBound:  116315.0
# added
# current object:  212222 , current distance:  143398.0 , lowerBound:  115951.0
# current object:  23358 , current distance:  161380.0 , lowerBound:  115951.0
# current object:  131563 , current distance:  108181.0 , lowerBound:  115951.0
# added
# current object:  38118 , current distance:  106321.0 , lowerBound:  115883.0
# added
# current object:  75229 , current distance:  121000.0 , lowerBound:  115729.0
# current object:  182230 , current distance:  105142.0 , lowerBound:  115729.0
# added
# current object:  312325 , current distance:  144653.0 , lowerBound:  115499.0
# current object:  77582 , current distance:  114197.0 , lowerBound:  115499.0
# added
# current object:  19225 , current distance:  118189.0 , lowerBound:  115465.0
# current object:  284269 , current distance:  138603.0 , lowerBound:  115465.0
# current object:  223420 , current distance:  105713.0 , lowerBound:  115465.0
# added
# current object:  74497 , current distance:  143940.0 , lowerBound:  115248.0
# current object:  163066 , current distance:  148088.0 , lowerBound:  115248.0
# current object:  207515 , current distance:  123162.0 , lowerBound:  115248.0
# current object:  31338 , current distance:  107263.0 , lowerBound:  115248.0
# added
# current object:  38660 , current distance:  103439.0 , lowerBound:  115145.0
# added
# current object:  182206 , visited already
# current object:  108024 , current distance:  131619.0 , lowerBound:  114932.0
# current object:  214117 , current distance:  115986.0 , lowerBound:  114932.0
# current object:  2913 , visited already
# current object:  125025 , current distance:  164360.0 , lowerBound:  114932.0
# current object:  79369 , current distance:  125528.0 , lowerBound:  114932.0
# current object:  74925 , current distance:  115465.0 , lowerBound:  114932.0
# current object:  74821 , current distance:  114725.0 , lowerBound:  114932.0
# added
# current object:  223427 , current distance:  116683.0 , lowerBound:  114747.0
# current object:  74861 , current distance:  118798.0 , lowerBound:  114747.0
# one node finishes
#
# current object:  210458
# size of neighbors:  27
# current object:  65237 , current distance:  139377.0 , lowerBound:  114747.0
# current object:  182255 , current distance:  154096.0 , lowerBound:  114747.0
# current object:  61293 , current distance:  141775.0 , lowerBound:  114747.0
# current object:  131560 , current distance:  113915.0 , lowerBound:  114747.0
# added
# current object:  74932 , current distance:  114745.0 , lowerBound:  114725.0
# current object:  205033 , current distance:  92598.0 , lowerBound:  114725.0
# added
# current object:  133224 , current distance:  141619.0 , lowerBound:  114544.0
# current object:  87927 , current distance:  131875.0 , lowerBound:  114544.0
# current object:  182237 , visited already
# current object:  36876 , current distance:  109150.0 , lowerBound:  114544.0
# added
# ...
# current object:  106311 , visited already
# current object:  209959 , visited already
# current object:  178142 , current distance:  162508.0 , lowerBound:  103090.0
# current object:  108989 , current distance:  133512.0 , lowerBound:  103090.0
# current object:  93855 , current distance:  102326.0 , lowerBound:  103090.0
# added
# current object:  240456 , current distance:  139741.0 , lowerBound:  102982.0
# current object:  280575 , current distance:  154151.0 , lowerBound:  102982.0
# current object:  280809 , current distance:  147415.0 , lowerBound:  102982.0
# current object:  282525 , visited already
# current object:  320427 , visited already
# current object:  341978 , current distance:  158093.0 , lowerBound:  102982.0
# current object:  351901 , current distance:  140236.0 , lowerBound:  102982.0
# current object:  352658 , current distance:  149748.0 , lowerBound:  102982.0
# one node finishes
#
# current object:  93855
# size of neighbors:  28
# current object:  175629 , current distance:  158760.0 , lowerBound:  102982.0
# current object:  37977 , current distance:  142454.0 , lowerBound:  102982.0
# current object:  45076 , current distance:  135680.0 , lowerBound:  102982.0
# current object:  242307 , current distance:  124461.0 , lowerBound:  102982.0
# current object:  43327 , visited already
# current object:  287962 , current distance:  114571.0 , lowerBound:  102982.0
# current object:  317864 , visited already
# current object:  284870 , current distance:  138952.0 , lowerBound:  102982.0
# current object:  224640 , current distance:  126463.0 , lowerBound:  102982.0
# current object:  125273 , visited already
# current object:  105067 , current distance:  141485.0 , lowerBound:  102982.0
# current object:  290977 , current distance:  134047.0 , lowerBound:  102982.0
# current object:  45066 , current distance:  141502.0 , lowerBound:  102982.0
# current object:  71897 , visited already
# current object:  53643 , current distance:  133947.0 , lowerBound:  102982.0
# current object:  210045 , current distance:  129935.0 , lowerBound:  102982.0
# current object:  175740 , current distance:  131942.0 , lowerBound:  102982.0
# current object:  105003 , current distance:  139143.0 , lowerBound:  102982.0
# current object:  319538 , current distance:  155615.0 , lowerBound:  102982.0
# current object:  87983 , current distance:  130137.0 , lowerBound:  102982.0
# current object:  233854 , current distance:  106234.0 , lowerBound:  102982.0
# current object:  28823 , current distance:  149121.0 , lowerBound:  102982.0
# current object:  14554 , current distance:  121316.0 , lowerBound:  102982.0
# current object:  158671 , visited already
# current object:  320067 , current distance:  165729.0 , lowerBound:  102982.0
# current object:  327213 , current distance:  170844.0 , lowerBound:  102982.0
# current object:  345215 , current distance:  132657.0 , lowerBound:  102982.0
# current object:  355027 , current distance:  122514.0 , lowerBound:  102982.0
# one node finishes
#
# current object:  95856
# size of neighbors:  32
# current object:  161332 , current distance:  144419.0 , lowerBound:  102982.0
# current object:  101009 , current distance:  126111.0 , lowerBound:  102982.0
# current object:  133080 , current distance:  128963.0 , lowerBound:  102982.0
# current object:  99823 , current distance:  131809.0 , lowerBound:  102982.0
# current object:  12486 , current distance:  120094.0 , lowerBound:  102982.0
# current object:  74999 , current distance:  108157.0 , lowerBound:  102982.0
# current object:  55067 , current distance:  170881.0 , lowerBound:  102982.0
# current object:  37931 , current distance:  136911.0 , lowerBound:  102982.0
# current object:  2118 , current distance:  160093.0 , lowerBound:  102982.0
# current object:  9005 , current distance:  148168.0 , lowerBound:  102982.0
# current object:  191864 , visited already
# current object:  189923 , current distance:  141441.0 , lowerBound:  102982.0
# current object:  98478 , current distance:  137590.0 , lowerBound:  102982.0
# current object:  181907 , current distance:  137468.0 , lowerBound:  102982.0
# current object:  111402 , current distance:  133989.0 , lowerBound:  102982.0
# current object:  64983 , current distance:  140479.0 , lowerBound:  102982.0
# current object:  149048 , current distance:  118198.0 , lowerBound:  102982.0
# current object:  205880 , visited already
# current object:  98409 , visited already
# current object:  204315 , current distance:  127761.0 , lowerBound:  102982.0
# current object:  9579 , current distance:  142553.0 , lowerBound:  102982.0
# current object:  83574 , current distance:  132764.0 , lowerBound:  102982.0
# current object:  214054 , current distance:  114988.0 , lowerBound:  102982.0
# current object:  217228 , visited already
# current object:  227857 , current distance:  155829.0 , lowerBound:  102982.0
# current object:  231700 , current distance:  169484.0 , lowerBound:  102982.0
# current object:  263228 , visited already
# current object:  291850 , visited already
# current object:  297695 , current distance:  165334.0 , lowerBound:  102982.0
# current object:  301867 , current distance:  151002.0 , lowerBound:  102982.0
# current object:  317992 , current distance:  138729.0 , lowerBound:  102982.0
# current object:  341625 , current distance:  136494.0 , lowerBound:  102982.0
# one node finishes
#
# current object:  349013
# size of neighbors:  16
# current object:  322205 , visited already
# current object:  228557 , visited already
# current object:  145638 , current distance:  171103.0 , lowerBound:  102982.0
# current object:  283633 , current distance:  178938.0 , lowerBound:  102982.0
# current object:  249757 , visited already
# current object:  46785 , current distance:  142938.0 , lowerBound:  102982.0
# current object:  163552 , current distance:  152005.0 , lowerBound:  102982.0
# current object:  62909 , current distance:  115122.0 , lowerBound:  102982.0
# current object:  7231 , current distance:  129269.0 , lowerBound:  102982.0
# current object:  237502 , current distance:  108296.0 , lowerBound:  102982.0
# current object:  4313 , current distance:  144084.0 , lowerBound:  102982.0
# current object:  283856 , current distance:  146080.0 , lowerBound:  102982.0
# current object:  132900 , visited already
# current object:  79400 , current distance:  158724.0 , lowerBound:  102982.0
# current object:  133322 , current distance:  117493.0 , lowerBound:  102982.0
# current object:  64878 , current distance:  152414.0 , lowerBound:  102982.0
# one node finishes
#
# current object:  162585
# size of neighbors:  29
# current object:  270223 , current distance:  133058.0 , lowerBound:  102982.0
# current object:  163139 , current distance:  142513.0 , lowerBound:  102982.0
# current object:  204046 , current distance:  141300.0 , lowerBound:  102982.0
# current object:  175228 , current distance:  106787.0 , lowerBound:  102982.0
# current object:  199835 , current distance:  142290.0 , lowerBound:  102982.0
# current object:  282452 , current distance:  147141.0 , lowerBound:  102982.0
# current object:  35947 , current distance:  164114.0 , lowerBound:  102982.0
# current object:  29627 , current distance:  169792.0 , lowerBound:  102982.0
# current object:  101574 , current distance:  146657.0 , lowerBound:  102982.0
# current object:  210297 , visited already
# current object:  238042 , current distance:  147936.0 , lowerBound:  102982.0
# current object:  225089 , current distance:  135618.0 , lowerBound:  102982.0
# current object:  51167 , current distance:  114007.0 , lowerBound:  102982.0
# current object:  66731 , current distance:  133586.0 , lowerBound:  102982.0
# current object:  141877 , visited already
# current object:  77024 , current distance:  148877.0 , lowerBound:  102982.0
# current object:  76953 , visited already
# current object:  97066 , visited already
# current object:  170594 , current distance:  129504.0 , lowerBound:  102982.0
# current object:  28532 , current distance:  117824.0 , lowerBound:  102982.0
# current object:  59716 , current distance:  146816.0 , lowerBound:  102982.0
# current object:  279889 , current distance:  108139.0 , lowerBound:  102982.0
# current object:  201244 , current distance:  151460.0 , lowerBound:  102982.0
# current object:  91941 , current distance:  145804.0 , lowerBound:  102982.0
# current object:  66070 , current distance:  136842.0 , lowerBound:  102982.0
# current object:  324636 , current distance:  139304.0 , lowerBound:  102982.0
# current object:  331383 , current distance:  167531.0 , lowerBound:  102982.0
# current object:  342831 , current distance:  134418.0 , lowerBound:  102982.0
# current object:  351200 , current distance:  127588.0 , lowerBound:  102982.0
# one node finishes
#
# current object:  103674
# size of neighbors:  28
# current object:  91250 , current distance:  149665.0 , lowerBound:  102982.0
# current object:  178241 , current distance:  156314.0 , lowerBound:  102982.0
# current object:  104758 , current distance:  100702.0 , lowerBound:  102982.0
# added
# current object:  101104 , current distance:  148326.0 , lowerBound:  102965.0
# current object:  106290 , current distance:  150528.0 , lowerBound:  102965.0
# current object:  10034 , current distance:  172120.0 , lowerBound:  102965.0
# current object:  105193 , visited already
# current object:  77215 , current distance:  120698.0 , lowerBound:  102965.0
# current object:  133669 , current distance:  127188.0 , lowerBound:  102965.0
# current object:  96353 , current distance:  149022.0 , lowerBound:  102965.0
# current object:  172352 , current distance:  119095.0 , lowerBound:  102965.0
# current object:  52054 , current distance:  170186.0 , lowerBound:  102965.0
# current object:  81991 , visited already
# current object:  205936 , current distance:  132997.0 , lowerBound:  102965.0
# current object:  31601 , visited already
# current object:  223514 , current distance:  144944.0 , lowerBound:  102965.0
# current object:  194909 , current distance:  169491.0 , lowerBound:  102965.0
# current object:  4665 , current distance:  110940.0 , lowerBound:  102965.0
# current object:  152506 , current distance:  164177.0 , lowerBound:  102965.0
# current object:  134421 , current distance:  123363.0 , lowerBound:  102965.0
# current object:  185490 , current distance:  145741.0 , lowerBound:  102965.0
# current object:  182237 , visited already
# current object:  134041 , current distance:  165819.0 , lowerBound:  102965.0
# current object:  256121 , current distance:  169608.0 , lowerBound:  102965.0
# current object:  263819 , current distance:  165088.0 , lowerBound:  102965.0
# current object:  313447 , current distance:  139648.0 , lowerBound:  102965.0
# current object:  332008 , current distance:  121526.0 , lowerBound:  102965.0
# current object:  333788 , current distance:  179358.0 , lowerBound:  102965.0
# one node finishes
#
# current object:  104758
# size of neighbors:  25
# current object:  36796 , current distance:  142940.0 , lowerBound:  102965.0
# current object:  62483 , current distance:  163679.0 , lowerBound:  102965.0
# current object:  12544 , current distance:  130234.0 , lowerBound:  102965.0
# current object:  65590 , current distance:  164515.0 , lowerBound:  102965.0
# current object:  103674 , visited already
# current object:  23044 , current distance:  168813.0 , lowerBound:  102965.0
# current object:  74847 , visited already
# current object:  94316 , current distance:  150833.0 , lowerBound:  102965.0
# current object:  66055 , current distance:  153846.0 , lowerBound:  102965.0
# current object:  35604 , visited already
# current object:  96094 , current distance:  137686.0 , lowerBound:  102965.0
# current object:  85656 , visited already
# current object:  77594 , current distance:  125262.0 , lowerBound:  102965.0
# current object:  82990 , visited already
# current object:  75124 , current distance:  122487.0 , lowerBound:  102965.0
# current object:  52409 , current distance:  107906.0 , lowerBound:  102965.0
# current object:  106480 , visited already
# current object:  119834 , current distance:  153890.0 , lowerBound:  102965.0
# current object:  128019 , current distance:  158943.0 , lowerBound:  102965.0
# current object:  143849 , current distance:  152760.0 , lowerBound:  102965.0
# current object:  153718 , visited already
# current object:  175883 , current distance:  124093.0 , lowerBound:  102965.0
# current object:  186893 , current distance:  121905.0 , lowerBound:  102965.0
# current object:  255409 , current distance:  131373.0 , lowerBound:  102965.0
# current object:  302543 , current distance:  149389.0 , lowerBound:  102965.0
# one node finishes
#
# current object:  125070
# size of neighbors:  32
# current object:  150905 , current distance:  157160.0 , lowerBound:  102965.0
# current object:  274221 , current distance:  167844.0 , lowerBound:  102965.0
# current object:  282464 , current distance:  141939.0 , lowerBound:  102965.0
# current object:  154401 , current distance:  140886.0 , lowerBound:  102965.0
# current object:  138401 , current distance:  159323.0 , lowerBound:  102965.0
# current object:  216427 , current distance:  150660.0 , lowerBound:  102965.0
# current object:  45117 , current distance:  114277.0 , lowerBound:  102965.0
# current object:  94446 , current distance:  140556.0 , lowerBound:  102965.0
# current object:  35857 , current distance:  128857.0 , lowerBound:  102965.0
# current object:  57441 , current distance:  137784.0 , lowerBound:  102965.0
# current object:  68017 , visited already
# current object:  19244 , current distance:  139275.0 , lowerBound:  102965.0
# current object:  281628 , current distance:  141693.0 , lowerBound:  102965.0
# current object:  197964 , current distance:  146141.0 , lowerBound:  102965.0
# current object:  317788 , current distance:  107313.0 , lowerBound:  102965.0
# current object:  284009 , visited already
# current object:  85036 , visited already
# current object:  202445 , current distance:  144106.0 , lowerBound:  102965.0
# current object:  132376 , current distance:  119746.0 , lowerBound:  102965.0
# current object:  107795 , current distance:  121358.0 , lowerBound:  102965.0
# current object:  291897 , current distance:  110422.0 , lowerBound:  102965.0
# current object:  75533 , visited already
# current object:  101278 , current distance:  150912.0 , lowerBound:  102965.0
# current object:  299656 , visited already
# current object:  150911 , current distance:  130083.0 , lowerBound:  102965.0
# current object:  121286 , current distance:  137275.0 , lowerBound:  102965.0
# current object:  26033 , visited already
# current object:  8194 , current distance:  148535.0 , lowerBound:  102965.0
# current object:  334390 , current distance:  156851.0 , lowerBound:  102965.0
# current object:  58975 , visited already
# current object:  183855 , current distance:  122141.0 , lowerBound:  102965.0
# current object:  233286 , current distance:  125184.0 , lowerBound:  102965.0
# one node finishes
#
# current object:  217153
# size of neighbors:  17
# current object:  211487 , current distance:  181902.0 , lowerBound:  102965.0
# current object:  210150 , visited already
# current object:  151985 , current distance:  179173.0 , lowerBound:  102965.0
# current object:  64878 , visited already
# current object:  97896 , current distance:  159297.0 , lowerBound:  102965.0
# current object:  202724 , current distance:  154129.0 , lowerBound:  102965.0
# current object:  196399 , current distance:  172146.0 , lowerBound:  102965.0
# current object:  38098 , current distance:  129373.0 , lowerBound:  102965.0
# current object:  12698 , visited already
# current object:  185036 , current distance:  184271.0 , lowerBound:  102965.0
# current object:  37214 , current distance:  153919.0 , lowerBound:  102965.0
# current object:  196434 , current distance:  164517.0 , lowerBound:  102965.0
# current object:  175882 , visited already
# current object:  136308 , current distance:  138260.0 , lowerBound:  102965.0
# current object:  182263 , visited already
# current object:  8401 , current distance:  133782.0 , lowerBound:  102965.0
# current object:  329422 , current distance:  129637.0 , lowerBound:  102965.0
# one node finishes

# %%
print(search_remote)
print(results)
print(local_results)
print(remote_results)
print(gt[0][0])
# Out:
# False
# [(61125.0, 0, 504814)]
# [[61125.0, 0, 504814]]
# [(112004.0, 1, 225145)]
# 504814

# %%
result_list = []
search_remote_list = []
query_num = 100

for i in range(query_num):
    results, local_results, remote_results, search_remote, remote_server_ID = HNSW_index.searchKnnPlusRemoteCache(hnsw_index, xq[i], k=1, ef=128, all_vectors=xb, debug=False)
    result_list.append(results[-1])
    search_remote_list.append(search_remote)

# %%
## Get recall for consider up to 1 remote hop
## Wenqi comment: even just 1 hop can reach xx% recall!!!
# First 100 queries -> 0.xx recall
# First 1000 queries -> 0.xxx recall
# First 10000 queries -> 0.xx recall (visit remote graph = 0.9978)

count = 0
for i in range(query_num):
    ID = result_list[i][2]
    if ID == gt[i][0]: count += 1
print(count/query_num, count)
# Out:
# 0.55 55

# %%
result_list
# Out:
# [(61125.0, 0, 504814),
#  (90500.0, 1, 481578),
#  (49682.0, 0, 552515),
#  (67326.0, 2, 341623),
#  (86317.0, 1, 536507),
#  (36847.0, 2, 188730),
#  (19658.0, 2, 572053),
#  (77786.0, 0, 327960),
#  (61815.0, 3, 452279),
#  (44113.0, 2, 592948),
#  (123587.0, 1, 682344),
#  (53513.0, 3, 771023),
#  (90584.0, 3, 826761),
#  (63552.0, 1, 717949),
#  (74573.0, 2, 468791),
#  (89593.0, 0, 776345),
#  (76238.0, 3, 560049),
#  (68137.0, 1, 368300),
#  (44529.0, 1, 495223),
#  (69042.0, 3, 172071),
#  (67778.0, 0, 68023),
#  (54462.0, 0, 671173),
#  (71914.0, 1, 8813),
#  (101565.0, 1, 609333),
#  (81364.0, 1, 658686),
#  (53304.0, 2, 838692),
#  (60544.0, 1, 397855),
#  (47047.0, 0, 221028),
#  (59493.0, 0, 962851),
#  (75169.0, 1, 191053),
#  (58396.0, 0, 425493),
#  (64474.0, 2, 181775),
#  (74212.0, 2, 588756),
#  (82034.0, 1, 226194),
#  (79119.0, 3, 144178),
#  (80708.0, 2, 860667),
#  (63324.0, 0, 602485),
#  (47917.0, 0, 812777),
#  (43526.0, 0, 341091),
#  (48413.0, 0, 856200),
#  (57088.0, 2, 409148),
#  (17417.0, 0, 499763),
#  (55637.0, 1, 550479),
#  (39624.0, 0, 43368),
#  (75486.0, 1, 562500),
#  (87053.0, 2, 76924),
#  (44058.0, 0, 436180),
#  (50406.0, 0, 283703),
#  (45782.0, 0, 28097),
#  (63819.0, 2, 426503),
#  (31174.0, 2, 41121),
#  (23245.0, 0, 467756),
#  (76986.0, 3, 803688),
#  (60554.0, 3, 623779),
#  (21567.0, 0, 819365),
#  (33124.0, 1, 882827),
#  (67169.0, 2, 489240),
#  (39355.0, 0, 779586),
#  (86402.0, 1, 702690),
#  (98595.0, 3, 956142),
#  (54214.0, 0, 534495),
#  (71184.0, 3, 895845),
#  (38293.0, 2, 915520),
#  (31981.0, 2, 45494),
#  (97322.0, 3, 855738),
#  (93054.0, 0, 809566),
#  (55459.0, 2, 400596),
#  (23242.0, 2, 850184),
#  (62033.0, 3, 972430),
#  (50585.0, 0, 434096),
#  (79820.0, 0, 116383),
#  (71111.0, 0, 753756),
#  (53763.0, 2, 549883),
#  (44422.0, 2, 257746),
#  (32479.0, 0, 436415),
#  (52473.0, 0, 629700),
#  (65714.0, 0, 470987),
#  (31634.0, 0, 717995),
#  (30022.0, 0, 680004),
#  (19413.0, 0, 694111),
#  (73113.0, 2, 435870),
#  (79638.0, 0, 380662),
#  (61949.0, 0, 555466),
#  (74805.0, 0, 34810),
#  (87083.0, 1, 267563),
#  (59383.0, 0, 853398),
#  (14175.0, 2, 299980),
#  (86137.0, 1, 138742),
#  (108506.0, 1, 253536),
#  (72417.0, 1, 158669),
#  (37929.0, 2, 32380),
#  (47896.0, 2, 914459),
#  (61914.0, 0, 190435),
#  (74193.0, 3, 617987),
#  (63422.0, 2, 923573),
#  (40884.0, 2, 330662),
#  (52351.0, 2, 732058),
#  (26679.0, 2, 763985),
#  (85603.0, 1, 140717),
#  (56868.0, 0, 72670)]

# %%
# Count how many searches travel to remote node
search_remote_count = 0
for i in range(query_num):
    if search_remote_list[i]: search_remote_count += 1
print(search_remote_count/query_num, search_remote_count)

# %%
# Search local + remote when needed
HNSW_index.searchKnnPlusRemote(
    hnsw_index, xq[0], k=10, ef=128, all_vectors=xb, 
    remote_hnswlib_indexes=remote_hnswlib_indexes, remote_server_IDs=remote_server_IDs, debug=False)
# Out:
# ([(61125.0, 0, 504814),
#   (62943.0, 0, 344333),
#   (73660.0, 0, 900184),
#   (77284.0, 0, 657385),
#   (77515.0, 0, 205768),
#   (80082.0, 0, 278818),
#   (82498.0, 0, 831624),
#   (83564.0, 0, 885651),
#   (84903.0, 0, 504835),
#   (85222.0, 0, 504547)],
#  False)

# %%
result_list = []
search_remote_list = []
query_num = 100

for i in range(query_num):
    results, search_remote = HNSW_index.searchKnnPlusRemote(
        hnsw_index, xq[i], k=1, ef=128, all_vectors=xb, 
        remote_hnswlib_indexes=remote_hnswlib_indexes, remote_server_IDs=remote_server_IDs, debug=False)
    result_list.append(results[-1])
    search_remote_list.append(search_remote)

# %%
## Get recall for consider up to 1 remote hop
## Wenqi comment: for k-means-based method, if you start from a bad parition, 
#    you may not end up getting the true nearest neighbor!
# First 100 queries -> 0.9 recall
# First 1000 queries -> 0.xxx recall
# First 10000 queries -> 0.xx recall (visit remote graph = 0.9978)

count = 0
for i in range(query_num):
    ID = result_list[i][2]
    if ID == gt[i][0]: count += 1
print(count/query_num, count)
# Out:
# 0.9 90

# %%
# Count how many searches travel to remote node
search_remote_count = 0
for i in range(query_num):
    if search_remote_list[i]: search_remote_count += 1
print(search_remote_count/query_num, search_remote_count)
# Out:
# 0.62 62
